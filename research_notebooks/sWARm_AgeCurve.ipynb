# %% [markdown]
# # sWARm Age Curve Analysis - SYSTEM 2 Joint Modeling
#
# This notebook implements and demonstrates the joint longitudinal-survival modeling approach for baseball player aging curves, integrated with the sWARm SYSTEM 2 future projection framework.
#
# ## Key Features:
# - **Joint Modeling**: Combines performance trajectory with retirement risk
# - **3-Year Projections**: 2025, 2026, 2027 future performance
# - **Interactive Analysis**: Player-specific historical validation and projections
# - **Age Curve Integration**: Position-specific aging patterns
# - **Expected Stats**: 75/25 weighting of real vs expected performance
#
# ## Model Architecture:
# - **Longitudinal Component**: MultiTaskLasso for multi-year WAR prediction
# - **Survival Component**: Cox Proportional Hazards for retirement risk
# - **Joint Estimation**: Addresses selection bias in aging curves

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import warnings
from datetime import datetime
import sys
import os

# Add modules to path
sys.path.append('.')

# Import sWARm modules
from current_season_modules.temp_modeling import prepare_data_for_kfold, run_kfold_cross_validation
from old.age_curve import (
    AgeDataLoader, ExpectedStatsCalculator, FutureProjectionAgeCurve, 
    AgeCurveValidator, integrate_age_curves_system2
)
from current_season_modules.two_way_players import get_cleaned_two_way_data
from legacy_modules.positional_adjustments import load_positional_adjustments_for_war_models

# Configure plotting
plt.style.use('default')
sns.set_palette("husl")
warnings.filterwarnings('ignore')

print("sWARm Age Curve Analysis - SYSTEM 2 Joint Modeling")
print("=" * 60)
print(f"Analysis Date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("\nInitialization Complete!")
# Out:
# sWARm Age Curve Analysis - SYSTEM 2 Joint Modeling
# ============================================================
# Analysis Date: 2025-09-25 17:40:49
#
# Initialization Complete!

# %% [markdown]
# ## Section 1: Data Preparation and Model Training
#
# This section prepares the comprehensive dataset and trains the joint longitudinal-survival model using the sWARm SYSTEM 2 framework.

# %%
# Load and prepare comprehensive dataset for age curve modeling
print("SECTION 1: DATA PREPARATION AND MODEL TRAINING")
print("=" * 50)

# Load base data using existing sWARm pipeline
print("\n1.1: Loading base data with sWARm SYSTEM 2 pipeline...")
hitter_data, pitcher_data = prepare_data_for_kfold()

print(f"✓ Hitter data loaded: {len(hitter_data['warp']) if hitter_data and 'warp' in hitter_data else 0} WARP records")
print(f"✓ Hitter data loaded: {len(hitter_data['war']) if hitter_data and 'war' in hitter_data else 0} WAR records")
print(f"✓ Pitcher data loaded: {len(pitcher_data['warp']) if pitcher_data and 'warp' in pitcher_data else 0} WARP records")
print(f"✓ Pitcher data loaded: {len(pitcher_data['war']) if pitcher_data and 'war' in pitcher_data else 0} WAR records")
# Out:
# SECTION 1: DATA PREPARATION AND MODEL TRAINING
# ==================================================
#
# 1.1: Loading base data with sWARm SYSTEM 2 pipeline...
# Preparing comprehensive dataset for K-fold cross-validation...
# Loading FIXED BP data with derived statistics...
# LOADING BP DATA WITH FIXED DERIVED STATISTICS
# ============================================================
#
# Processing BP Hitter Data:
#    Calculating derived statistics for 2016 data...
#       DATA: K%: 633/633 records have valid values
#       DATA: BB%: 633/633 records have valid values
#    SUCCESS 2016: 633 records loaded
#    Calculating derived statistics for 2017 data...
#       DATA: K%: 623/623 records have valid values
#       DATA: BB%: 623/623 records have valid values
#    SUCCESS 2017: 623 records loaded
#    Calculating derived statistics for 2018 data...
#       DATA: K%: 627/627 records have valid values
#       DATA: BB%: 627/627 records have valid values
#    SUCCESS 2018: 627 records loaded
#    Calculating derived statistics for 2019 data...
#       DATA: K%: 990/990 records have valid values
#       DATA: BB%: 990/990 records have valid values
#    SUCCESS 2019: 990 records loaded
#    OK: 2020 data already has K% and BB% - no calculation needed
#    SUCCESS 2020: 581 records loaded
#    OK: 2021 data already has K% and BB% - no calculation needed
#    SUCCESS 2021: 1049 records loaded
#    OK: 2022 data already has K% and BB% - no calculation needed
#    SUCCESS 2022: 693 records loaded
#    OK: 2023 data already has K% and BB% - no calculation needed
#    SUCCESS 2023: 656 records loaded
#    OK: 2024 data already has K% and BB% - no calculation needed
#    SUCCESS 2024: 651 records loaded
#
# Processing BP Pitcher Data:
#    Calculating derived statistics for 2016 data...
#       DATA: K%: 742/742 records have valid values
#       DATA: BB%: 742/742 records have valid values
#    SUCCESS 2016: 742 records loaded
#    Calculating derived statistics for 2017 data...
#       DATA: K%: 755/755 records have valid values
#       DATA: BB%: 755/755 records have valid values
#    SUCCESS 2017: 755 records loaded
#    Calculating derived statistics for 2018 data...
#       DATA: K%: 799/799 records have valid values
#       DATA: BB%: 799/799 records have valid values
#    SUCCESS 2018: 799 records loaded
#    Calculating derived statistics for 2019 data...
#       DATA: K%: 831/831 records have valid values
#       DATA: BB%: 831/831 records have valid values
#    SUCCESS 2019: 831 records loaded
#    OK: 2020 data already has K% and BB% - no calculation needed
#    SUCCESS 2020: 735 records loaded
#    OK: 2021 data already has K% and BB% - no calculation needed
#    SUCCESS 2021: 909 records loaded
#    OK: 2022 data already has K% and BB% - no calculation needed
#    SUCCESS 2022: 871 records loaded
#    OK: 2023 data already has K% and BB% - no calculation needed
#    SUCCESS 2023: 863 records loaded
#    OK: 2024 data already has K% and BB% - no calculation needed
#    SUCCESS 2024: 840 records loaded
#
# Combined Hitter Data: 6503 total records
#    K% coverage: 100.0%
#    BB% coverage: 100.0%
#
# Combined Pitcher Data: 7345 total records
#    K% coverage: 100.0%
#    BB% coverage: 100.0%
#
# SUCCESS: BP DATA LOADING WITH DERIVED STATISTICS COMPLETE!
# Loading EXPANDED FanGraphs data...
# Loading expanded FanGraphs hitter data...
#    SUCCESS 2016: 633 hitter records loaded
#    SUCCESS 2017: 625 hitter records loaded
#    SUCCESS 2018: 629 hitter records loaded
#    SUCCESS 2019: 635 hitter records loaded
#    SUCCESS 2020: 581 hitter records loaded
#    SUCCESS 2021: 661 hitter records loaded
#    SUCCESS 2022: 690 hitter records loaded
#    SUCCESS 2023: 655 hitter records loaded
#    SUCCESS 2024: 651 hitter records loaded
#
# Expanded FanGraphs hitter data: 5760 total records
#    PA range: 0 to 753
#    Players with 0 PA: 15
#    Players with <100 PA: 1830
#    Players with 400+ PA: 1652
# Filtering pitchers from WAR hitting data...
# LOADING BP DATA WITH FIXED DERIVED STATISTICS
# ============================================================
#
# Processing BP Hitter Data:
#    Calculating derived statistics for 2016 data...
#       DATA: K%: 633/633 records have valid values
#       DATA: BB%: 633/633 records have valid values
#    SUCCESS 2016: 633 records loaded
#    Calculating derived statistics for 2017 data...
#       DATA: K%: 623/623 records have valid values
#       DATA: BB%: 623/623 records have valid values
#    SUCCESS 2017: 623 records loaded
#    Calculating derived statistics for 2018 data...
#       DATA: K%: 627/627 records have valid values
#       DATA: BB%: 627/627 records have valid values
#    SUCCESS 2018: 627 records loaded
#    Calculating derived statistics for 2019 data...
#       DATA: K%: 990/990 records have valid values
#       DATA: BB%: 990/990 records have valid values
#    SUCCESS 2019: 990 records loaded
#    OK: 2020 data already has K% and BB% - no calculation needed
#    SUCCESS 2020: 581 records loaded
#    OK: 2021 data already has K% and BB% - no calculation needed
#    SUCCESS 2021: 1049 records loaded
#    OK: 2022 data already has K% and BB% - no calculation needed
#    SUCCESS 2022: 693 records loaded
#    OK: 2023 data already has K% and BB% - no calculation needed
#    SUCCESS 2023: 656 records loaded
#    OK: 2024 data already has K% and BB% - no calculation needed
#    SUCCESS 2024: 651 records loaded
#
# Processing BP Pitcher Data:
#    Calculating derived statistics for 2016 data...
#       DATA: K%: 742/742 records have valid values
#       DATA: BB%: 742/742 records have valid values
#    SUCCESS 2016: 742 records loaded
#    Calculating derived statistics for 2017 data...
#       DATA: K%: 755/755 records have valid values
#       DATA: BB%: 755/755 records have valid values
#    SUCCESS 2017: 755 records loaded
#    Calculating derived statistics for 2018 data...
#       DATA: K%: 799/799 records have valid values
#       DATA: BB%: 799/799 records have valid values
#    SUCCESS 2018: 799 records loaded
#    Calculating derived statistics for 2019 data...
#       DATA: K%: 831/831 records have valid values
#       DATA: BB%: 831/831 records have valid values
#    SUCCESS 2019: 831 records loaded
#    OK: 2020 data already has K% and BB% - no calculation needed
#    SUCCESS 2020: 735 records loaded
#    OK: 2021 data already has K% and BB% - no calculation needed
#    SUCCESS 2021: 909 records loaded
#    OK: 2022 data already has K% and BB% - no calculation needed
#    SUCCESS 2022: 871 records loaded
#    OK: 2023 data already has K% and BB% - no calculation needed
#    SUCCESS 2023: 863 records loaded
#    OK: 2024 data already has K% and BB% - no calculation needed
#    SUCCESS 2024: 840 records loaded
#
# Combined Hitter Data: 6503 total records
#    K% coverage: 100.0%
#    BB% coverage: 100.0%
#
# Combined Pitcher Data: 7345 total records
#    K% coverage: 100.0%
#    BB% coverage: 100.0%
#
# SUCCESS: BP DATA LOADING WITH DERIVED STATISTICS COMPLETE!
#   Found 2267 pitcher names to potentially filter
#   2016: Removed 143 pitchers (pre-2020 rule)
#   2017: Removed 154 pitchers (pre-2020 rule)
#   2018: Removed 170 pitchers (pre-2020 rule)
#   2019: Removed 180 pitchers (pre-2020 rule)
#   2020: Removed 158 pitchers (2020+ rule, two-way logic TBD)
#   2021: Removed 177 pitchers (2020+ rule, two-way logic TBD)
#   2022: Removed 163 pitchers (2020+ rule, two-way logic TBD)
#   2023: Removed 140 pitchers (2020+ rule, two-way logic TBD)
#   2024: Removed 107 pitchers (2020+ rule, two-way logic TBD)
#   WAR hitting data: 5760 -> 4368 records after pitcher filtering
# Filtering pitchers from WARP hitting data...
# LOADING BP DATA WITH FIXED DERIVED STATISTICS
# ============================================================
#
# Processing BP Hitter Data:
#    Calculating derived statistics for 2016 data...
#       DATA: K%: 633/633 records have valid values
#       DATA: BB%: 633/633 records have valid values
#    SUCCESS 2016: 633 records loaded
#    Calculating derived statistics for 2017 data...
#       DATA: K%: 623/623 records have valid values
#       DATA: BB%: 623/623 records have valid values
#    SUCCESS 2017: 623 records loaded
#    Calculating derived statistics for 2018 data...
#       DATA: K%: 627/627 records have valid values
#       DATA: BB%: 627/627 records have valid values
#    SUCCESS 2018: 627 records loaded
#    Calculating derived statistics for 2019 data...
#       DATA: K%: 990/990 records have valid values
#       DATA: BB%: 990/990 records have valid values
#    SUCCESS 2019: 990 records loaded
#    OK: 2020 data already has K% and BB% - no calculation needed
#    SUCCESS 2020: 581 records loaded
#    OK: 2021 data already has K% and BB% - no calculation needed
#    SUCCESS 2021: 1049 records loaded
#    OK: 2022 data already has K% and BB% - no calculation needed
#    SUCCESS 2022: 693 records loaded
#    OK: 2023 data already has K% and BB% - no calculation needed
#    SUCCESS 2023: 656 records loaded
#    OK: 2024 data already has K% and BB% - no calculation needed
#    SUCCESS 2024: 651 records loaded
#
# Processing BP Pitcher Data:
#    Calculating derived statistics for 2016 data...
#       DATA: K%: 742/742 records have valid values
#       DATA: BB%: 742/742 records have valid values
#    SUCCESS 2016: 742 records loaded
#    Calculating derived statistics for 2017 data...
#       DATA: K%: 755/755 records have valid values
#       DATA: BB%: 755/755 records have valid values
#    SUCCESS 2017: 755 records loaded
#    Calculating derived statistics for 2018 data...
#       DATA: K%: 799/799 records have valid values
#       DATA: BB%: 799/799 records have valid values
#    SUCCESS 2018: 799 records loaded
#    Calculating derived statistics for 2019 data...
#       DATA: K%: 831/831 records have valid values
#       DATA: BB%: 831/831 records have valid values
#    SUCCESS 2019: 831 records loaded
#    OK: 2020 data already has K% and BB% - no calculation needed
#    SUCCESS 2020: 735 records loaded
#    OK: 2021 data already has K% and BB% - no calculation needed
#    SUCCESS 2021: 909 records loaded
#    OK: 2022 data already has K% and BB% - no calculation needed
#    SUCCESS 2022: 871 records loaded
#    OK: 2023 data already has K% and BB% - no calculation needed
#    SUCCESS 2023: 863 records loaded
#    OK: 2024 data already has K% and BB% - no calculation needed
#    SUCCESS 2024: 840 records loaded
#
# Combined Hitter Data: 6503 total records
#    K% coverage: 100.0%
#    BB% coverage: 100.0%
#
# Combined Pitcher Data: 7345 total records
#    K% coverage: 100.0%
#    BB% coverage: 100.0%
#
# SUCCESS: BP DATA LOADING WITH DERIVED STATISTICS COMPLETE!
#   Found 2267 pitcher names to potentially filter
#   2016: Removed 143 pitchers (pre-2020 rule)
#   2017: Removed 154 pitchers (pre-2020 rule)
#   2018: Removed 169 pitchers (pre-2020 rule)
#   2019: Removed 535 pitchers (pre-2020 rule)
#   2020: Removed 162 pitchers (2020+ rule, two-way logic TBD)
#   2021: Removed 566 pitchers (2020+ rule, two-way logic TBD)
#   2022: Removed 166 pitchers (2020+ rule, two-way logic TBD)
#   2023: Removed 143 pitchers (2020+ rule, two-way logic TBD)
#   2024: Removed 109 pitchers (2020+ rule, two-way logic TBD)
#   WARP hitting data: 6503 -> 4356 records after pitcher filtering
# Loading EXPANDED pitcher data...
# Loading expanded FanGraphs pitcher data...
#    SUCCESS 2016: 736 pitcher records loaded
#    SUCCESS 2017: 743 pitcher records loaded
#    SUCCESS 2018: 784 pitcher records loaded
#    SUCCESS 2019: 818 pitcher records loaded
#    SUCCESS 2020: 719 pitcher records loaded
#    SUCCESS 2021: 885 pitcher records loaded
#    SUCCESS 2022: 861 pitcher records loaded
#    SUCCESS 2023: 851 pitcher records loaded
#    SUCCESS 2024: 840 pitcher records loaded
#
# Expanded FanGraphs pitcher data: 7237 total records
#    Games range: 1 to 83
#    Pitchers with 0 G: 0
#    Pitchers with <10 G: 2303
#    Pitchers with 30+ G: 2378
# === COMPREHENSIVE TWO-WAY PLAYER ANALYSIS ===
# Using MLB criteria with FanGraphs and BP comprehensive data
# === COMPREHENSIVE TWO-WAY PLAYER ANALYSIS ===
# Using MLB criteria: 20+ IP pitching AND 20+ games/60+ PA hitting
# Loading comprehensive FanGraphs and BP data...
# === LOADING COMPREHENSIVE FANGRAPHS DATA (2016-2024) ===
# Combining 5 data types: Hitters (3), Pitchers (3), Defensive (2)
#
# Processing 2016...
#   Hitters basic: 633 players loaded
#   Pitchers basic: 736 players loaded
#   Defensive advanced: 2095 players loaded
#   Defensive standard: 2095 players loaded
#
# Processing 2017...
#   Hitters basic: 625 players loaded
#   Pitchers basic: 743 players loaded
#   Defensive advanced: 2111 players loaded
#   Defensive standard: 2111 players loaded
#
# Processing 2018...
#   Hitters basic: 629 players loaded
#   Pitchers basic: 784 players loaded
#   Defensive advanced: 2186 players loaded
#   Defensive standard: 2186 players loaded
#
# Processing 2019...
#   Hitters basic: 635 players loaded
#   Pitchers basic: 818 players loaded
#   Defensive advanced: 2249 players loaded
#   Defensive standard: 2249 players loaded
#
# Processing 2020...
#   Hitters basic: 581 players loaded
#   Pitchers basic: 719 players loaded
#   Defensive advanced: 1846 players loaded
#   Defensive standard: 1846 players loaded
#
# Processing 2021...
#   Hitters basic: 661 players loaded
#   Pitchers basic: 885 players loaded
#   Defensive advanced: 2410 players loaded
#   Defensive standard: 2410 players loaded
#
# Processing 2022...
#   Hitters basic: 690 players loaded
#   Pitchers basic: 861 players loaded
#   Defensive advanced: 2384 players loaded
#   Defensive standard: 2384 players loaded
#
# Processing 2023...
#   Hitters basic: 655 players loaded
#   Pitchers basic: 851 players loaded
#   Defensive advanced: 2273 players loaded
#   Defensive standard: 2273 players loaded
#
# Processing 2024...
#   Hitters basic: 651 players loaded
#   Pitchers basic: 840 players loaded
#   Defensive advanced: 2209 players loaded
#   Defensive standard: 2209 players loaded
#
# Cached comprehensive FanGraphs data:
#   Hitters: 5757 player-seasons
#   Pitchers: 7230 player-seasons
#   Defensive: 12537 player-seasons
# LOADING BP DATA WITH FIXED DERIVED STATISTICS
# ============================================================
#
# Processing BP Hitter Data:
#    Calculating derived statistics for 2016 data...
#       DATA: K%: 633/633 records have valid values
#       DATA: BB%: 633/633 records have valid values
#    SUCCESS 2016: 633 records loaded
#    Calculating derived statistics for 2017 data...
#       DATA: K%: 623/623 records have valid values
#       DATA: BB%: 623/623 records have valid values
#    SUCCESS 2017: 623 records loaded
#    Calculating derived statistics for 2018 data...
#       DATA: K%: 627/627 records have valid values
#       DATA: BB%: 627/627 records have valid values
#    SUCCESS 2018: 627 records loaded
#    Calculating derived statistics for 2019 data...
#       DATA: K%: 990/990 records have valid values
#       DATA: BB%: 990/990 records have valid values
#    SUCCESS 2019: 990 records loaded
#    OK: 2020 data already has K% and BB% - no calculation needed
#    SUCCESS 2020: 581 records loaded
#    OK: 2021 data already has K% and BB% - no calculation needed
#    SUCCESS 2021: 1049 records loaded
#    OK: 2022 data already has K% and BB% - no calculation needed
#    SUCCESS 2022: 693 records loaded
#    OK: 2023 data already has K% and BB% - no calculation needed
#    SUCCESS 2023: 656 records loaded
#    OK: 2024 data already has K% and BB% - no calculation needed
#    SUCCESS 2024: 651 records loaded
#
# Processing BP Pitcher Data:
#    Calculating derived statistics for 2016 data...
#       DATA: K%: 742/742 records have valid values
#       DATA: BB%: 742/742 records have valid values
#    SUCCESS 2016: 742 records loaded
#    Calculating derived statistics for 2017 data...
#       DATA: K%: 755/755 records have valid values
#       DATA: BB%: 755/755 records have valid values
#    SUCCESS 2017: 755 records loaded
#    Calculating derived statistics for 2018 data...
#       DATA: K%: 799/799 records have valid values
#       DATA: BB%: 799/799 records have valid values
#    SUCCESS 2018: 799 records loaded
#    Calculating derived statistics for 2019 data...
#       DATA: K%: 831/831 records have valid values
#       DATA: BB%: 831/831 records have valid values
#    SUCCESS 2019: 831 records loaded
#    OK: 2020 data already has K% and BB% - no calculation needed
#    SUCCESS 2020: 735 records loaded
#    OK: 2021 data already has K% and BB% - no calculation needed
#    SUCCESS 2021: 909 records loaded
#    OK: 2022 data already has K% and BB% - no calculation needed
#    SUCCESS 2022: 871 records loaded
#    OK: 2023 data already has K% and BB% - no calculation needed
#    SUCCESS 2023: 863 records loaded
#    OK: 2024 data already has K% and BB% - no calculation needed
#    SUCCESS 2024: 840 records loaded
#
# Combined Hitter Data: 6503 total records
#    K% coverage: 100.0%
#    BB% coverage: 100.0%
#
# Combined Pitcher Data: 7345 total records
#    K% coverage: 100.0%
#    BB% coverage: 100.0%
#
# SUCCESS: BP DATA LOADING WITH DERIVED STATISTICS COMPLETE!
#
# Analyzing 2016 season...
#   Found 18 MLBIDs appearing in both hitting and pitching data
#   CANDIDATE: JB Shuck (MLBID: 543776) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Rubén Tejada (MLBID: 514913) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Tyler Holt (MLBID: 534627) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jared Hoying (MLBID: 592419) - hitting (39G/49PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Eduardo Escobar (MLBID: 500871) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Miguel Montero (MLBID: 471083) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Tyler Ladendorf (MLBID: 502285) - hitting (45G/50PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Luis Sardinas (MLBID: 596143) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Ryan Flaherty (MLBID: 475247) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Ryan Goins (MLBID: 572365) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Drew Butera (MLBID: 460077) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Tyler White (MLBID: 643603) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Chris Gimenez (MLBID: 460269) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Christian Bethancourt (MLBID: 542194) - pitching (1.2IP, need 20IP)
#   CANDIDATE: Darwin Barney (MLBID: 446381) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Bryan Holaday (MLBID: 592407) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Erik Kratz (MLBID: 456124) - pitching (2.0IP, need 20IP)
#
# Analyzing 2017 season...
#   Found 20 MLBIDs appearing in both hitting and pitching data
#   CANDIDATE: Mike Freeman (MLBID: 502273) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Carlos Ruiz (MLBID: 434563) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Mitch Moreland (MLBID: 519048) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Tyler White (MLBID: 643603) - pitching (1.0IP, need 20IP)
#   CANDIDATE: J.D. Davis (MLBID: 605204) - pitching (1.2IP, need 20IP)
#   CANDIDATE: Andrew Romine (MLBID: 461865) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Michael Martinez (MLBID: 492841) - hitting (28G/43PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Miguel Montero (MLBID: 471083) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Luis Sardinas (MLBID: 596143) - hitting (29G/53PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Jesús Sucre (MLBID: 491696) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Scooter Gennett (MLBID: 571697) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Norichika Aoki (MLBID: 493114) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Kevin Plawecki (MLBID: 608700) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Brett Nicholas (MLBID: 592592) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Hernán Pérez (MLBID: 541650) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Daniel Descalso (MLBID: 518614) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Erick Aybar (MLBID: 430947) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Chris Gimenez (MLBID: 460269) - pitching (5.0IP, need 20IP)
#   CANDIDATE: Rob Brantly (MLBID: 542963) - hitting (14G/36PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Jon Jay (MLBID: 445055) - pitching (1.0IP, need 20IP)
#
# Analyzing 2018 season...
#   Found 40 MLBIDs appearing in both hitting and pitching data
#   CANDIDATE: Scott Kingery (MLBID: 664068) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Greg Garcia (MLBID: 594824) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jedd Gyorko (MLBID: 576397) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Johnny Field (MLBID: 608654) - pitching (1.0IP, need 20IP)
#   CANDIDATE: J.D. Davis (MLBID: 605204) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Bryan Holaday (MLBID: 592407) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Ryan Rua (MLBID: 607387) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Cliff Pennington (MLBID: 460060) - hitting (16G/34PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Andrew Romine (MLBID: 461865) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Jeff Mathis (MLBID: 425772) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Willians Astudillo (MLBID: 553902) - pitching (1.0IP, need 20IP)
#   QUALIFIED: Shohei Ohtani (MLBID: 660271) - 114G/367PA hitting, 51.2IP pitching
#   CANDIDATE: Jesús Sucre (MLBID: 491696) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Cory Spangenberg (MLBID: 605486) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Brandon Guyer (MLBID: 446386) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Charlie Culberson (MLBID: 518586) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Erik Kratz (MLBID: 456124) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Mitch Garver (MLBID: 641598) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Daniel Robertson (MLBID: 621002) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jace Peterson (MLBID: 607054) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Matt Davidson (MLBID: 571602) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Hernán Pérez (MLBID: 541650) - pitching (3.1IP, need 20IP)
#   CANDIDATE: Daniel Descalso (MLBID: 518614) - pitching (3.1IP, need 20IP)
#   CANDIDATE: Ian Happ (MLBID: 664023) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Pedro Florimón (MLBID: 465753) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Kendrys Morales (MLBID: 434778) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Alex Avila (MLBID: 488671) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Roman Quinn (MLBID: 596451) - pitching (1.2IP, need 20IP)
#   CANDIDATE: Alex Blandino (MLBID: 607468) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Taylor Motter (MLBID: 600301) - hitting (17G/38PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Chris Gimenez (MLBID: 460269) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Tommy La Stella (MLBID: 600303) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Pablo Sandoval (MLBID: 467055) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Victor Caratini (MLBID: 605170) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Chase d'Arnaud (MLBID: 488818) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jesmuel Valentín (MLBID: 621044) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Brandon Dixon (MLBID: 641525) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Francisco Arcia (MLBID: 516472) - pitching (3.0IP, need 20IP)
#   CANDIDATE: José Reyes (MLBID: 408314) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jake Smolinski (MLBID: 519295) - hitting (20G/41PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#
# Analyzing 2019 season...
#   Found 52 MLBIDs appearing in both hitting and pitching data
#   CANDIDATE: Mike Freeman (MLBID: 502273) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Ian Kinsler (MLBID: 435079) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Luke Maile (MLBID: 571912) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Kyle Farmer (MLBID: 571657) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Ben Zobrist (MLBID: 450314) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Caleb Joseph (MLBID: 543376) - hitting (20G/41PA, need 20G/60PA); pitching (1.1IP, need 20IP)
#   CANDIDATE: Sean Rodríguez (MLBID: 446481) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Tyler White (MLBID: 643603) - pitching (3.1IP, need 20IP)
#   CANDIDATE: Brian Dozier (MLBID: 572821) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Humberto Arteaga (MLBID: 600858) - pitching (1.2IP, need 20IP)
#   CANDIDATE: Richard Urena (MLBID: 620446) - pitching (1.0IP, need 20IP)
#   CANDIDATE: JB Shuck (MLBID: 543776) - hitting (27G/57PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Chris Davis (MLBID: 448801) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jared Walsh (MLBID: 665120) - pitching (5.0IP, need 20IP)
#   CANDIDATE: Ian Desmond (MLBID: 435622) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Eduardo Núñez (MLBID: 456488) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Mike Ford (MLBID: 645801) - pitching (2.0IP, need 20IP)
#   CANDIDATE: José Rondón (MLBID: 602922) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Russell Martin (MLBID: 431145) - pitching (4.0IP, need 20IP)
#   CANDIDATE: Tim Federowicz (MLBID: 543148) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Aaron Altherr (MLBID: 571437) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Dylan Moore (MLBID: 664238) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jeff Mathis (MLBID: 425772) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Jesús Sucre (MLBID: 491696) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Nick Martini (MLBID: 605361) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Austin Romine (MLBID: 519222) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Alex Gordon (MLBID: 460086) - pitching (2.1IP, need 20IP)
#   CANDIDATE: Ehire Adrianza (MLBID: 501303) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Charlie Culberson (MLBID: 518586) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Kevin Plawecki (MLBID: 608700) - pitching (2.0IP, need 20IP)
#   CANDIDATE: John Ryan Murphy (MLBID: 571974) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Daniel Robertson (MLBID: 621002) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Hernán Pérez (MLBID: 541650) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Tom Murphy (MLBID: 608596) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Daniel Descalso (MLBID: 518614) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Mark Reynolds (MLBID: 448602) - pitching (1.0IP, need 20IP)
#   CANDIDATE: José Peraza (MLBID: 606299) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Kendrys Morales (MLBID: 434778) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Stevie Wilkerson (MLBID: 592859) - pitching (5.1IP, need 20IP)
#   CANDIDATE: Alex Avila (MLBID: 488671) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Ty France (MLBID: 664034) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Roman Quinn (MLBID: 596451) - pitching (3.1IP, need 20IP)
#   CANDIDATE: Chris Owings (MLBID: 572008) - pitching (1.2IP, need 20IP)
#   CANDIDATE: Hanser Alberto (MLBID: 593643) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Pablo Sandoval (MLBID: 467055) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Victor Caratini (MLBID: 605170) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Jacob Stallings (MLBID: 607732) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Brandon Dixon (MLBID: 641525) - pitching (2.0IP, need 20IP)
#   CANDIDATE: AJ Reed (MLBID: 607223) - hitting (14G/49PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Mike Brosseau (MLBID: 670712) - pitching (4.0IP, need 20IP)
#   CANDIDATE: José Osuna (MLBID: 591741) - pitching (2.1IP, need 20IP)
#
# Analyzing 2020 season...
#   Found 21 MLBIDs appearing in both hitting and pitching data
#   CANDIDATE: Brock Holt (MLBID: 571788) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Jedd Gyorko (MLBID: 576397) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Tzu-Wei Lin (MLBID: 624407) - hitting (26G/57PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Orlando Arcia (MLBID: 606115) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Drew Butera (MLBID: 460077) - hitting (29G/43PA, need 20G/60PA); pitching (1.2IP, need 20IP)
#   CANDIDATE: Shohei Ohtani (MLBID: 660271) - pitching (1.2IP, need 20IP)
#   CANDIDATE: Ehire Adrianza (MLBID: 501303) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Todd Frazier (MLBID: 453943) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Erik Kratz (MLBID: 456124) - hitting (18G/30PA, need 20G/60PA); pitching (2.0IP, need 20IP)
#   CANDIDATE: Tyler Heineman (MLBID: 623168) - hitting (15G/50PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: John Ryan Murphy (MLBID: 571974) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Tim Lopes (MLBID: 621005) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Matt Davidson (MLBID: 571602) - hitting (22G/47PA, need 20G/60PA); pitching (3.1IP, need 20IP)
#   CANDIDATE: Anthony Bemboom (MLBID: 621532) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Carson Kelly (MLBID: 608348) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Travis Demeritte (MLBID: 641513) - hitting (18G/33PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Santiago Espinal (MLBID: 669289) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Luis Guillorme (MLBID: 641645) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Logan Forsythe (MLBID: 523253) - hitting (13G/38PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#
# Analyzing 2021 season...
#   Found 48 MLBIDs appearing in both hitting and pitching data
#   CANDIDATE: Eric Sogard (MLBID: 519299) - pitching (4.1IP, need 20IP)
#   CANDIDATE: Marwin Gonzalez (MLBID: 503556) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Yermín Mercedes (MLBID: 606213) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Wilmer Difo (MLBID: 594694) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Luke Maile (MLBID: 571912) - hitting (15G/34PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Mitch Moreland (MLBID: 519048) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Brock Holt (MLBID: 571788) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jonathan Araúz (MLBID: 660620) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Joshua Fuentes (MLBID: 658069) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Bryan Holaday (MLBID: 592407) - hitting (13G/34PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Jordan Luplow (MLBID: 656669) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Christian Arroyo (MLBID: 624414) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Justin Turner (MLBID: 457759) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Francisco Mejía (MLBID: 642336) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Adam Eaton (MLBID: 594809) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Austin Wynns (MLBID: 642851) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Andrew Romine (MLBID: 461865) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Harold Castro (MLBID: 605612) - pitching (2.2IP, need 20IP)
#   CANDIDATE: Willians Astudillo (MLBID: 553902) - pitching (4.0IP, need 20IP)
#   CANDIDATE: Albert Almora Jr. (MLBID: 546991) - hitting (47G/54PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   QUALIFIED: Shohei Ohtani (MLBID: 660271) - 158G/639PA hitting, 130.1IP pitching
#   CANDIDATE: Charlie Culberson (MLBID: 518586) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Kevin Plawecki (MLBID: 608700) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Wyatt Mathisen (MLBID: 621500) - hitting (23G/51PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: David Peralta (MLBID: 444482) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Danny Mendick (MLBID: 664901) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Asdrúbal Cabrera (MLBID: 452678) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Daniel Robertson (MLBID: 621002) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Darin Ruf (MLBID: 573131) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jace Peterson (MLBID: 607054) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Sandy León (MLBID: 506702) - pitching (6.0IP, need 20IP)
#   CANDIDATE: Max Schrock (MLBID: 621011) - pitching (1.2IP, need 20IP)
#   CANDIDATE: Ka'ai Tom (MLBID: 664789) - pitching (1.0IP, need 20IP)
#   CANDIDATE: John Nogowski (MLBID: 596056) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Robel García (MLBID: 596825) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Matt Carpenter (MLBID: 572761) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Stevie Wilkerson (MLBID: 592859) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Phillip Evans (MLBID: 595943) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Ronald Torreyes (MLBID: 591720) - pitching (2.2IP, need 20IP)
#   CANDIDATE: Alex Blandino (MLBID: 607468) - pitching (3.2IP, need 20IP)
#   CANDIDATE: Mike Tauchman (MLBID: 643565) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Luis Guillorme (MLBID: 641645) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Pat Valaika (MLBID: 642162) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Brett Phillips (MLBID: 621433) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jake Rogers (MLBID: 668670) - pitching (1.0IP, need 20IP)
#
# Analyzing 2022 season...
#   Found 62 MLBIDs appearing in both hitting and pitching data
#   CANDIDATE: Reese McGuire (MLBID: 624512) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Whit Merrifield (MLBID: 593160) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Corey Dickerson (MLBID: 572816) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jake Hager (MLBID: 606993) - hitting (28G/59PA, need 20G/60PA); pitching (2.1IP, need 20IP)
#   CANDIDATE: Albert Pujols (MLBID: 405395) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Garrett Stubbs (MLBID: 596117) - pitching (3.2IP, need 20IP)
#   CANDIDATE: Phil Gosselin (MLBID: 594838) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Yu Chang (MLBID: 644374) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Yadier Molina (MLBID: 425877) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Brian Serven (MLBID: 661531) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Diego Castillo (MLBID: 660636) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Luis Torrens (MLBID: 620443) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Michael A. Taylor (MLBID: 572191) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Franmil Reyes (MLBID: 614177) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Austin Wynns (MLBID: 642851) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Orlando Arcia (MLBID: 606115) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Ernie Clement (MLBID: 676391) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Mike Ford (MLBID: 645801) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Harold Castro (MLBID: 605612) - pitching (4.0IP, need 20IP)
#   CANDIDATE: Jack Mayfield (MLBID: 608686) - pitching (1.0IP, need 20IP)
#   QUALIFIED: Shohei Ohtani (MLBID: 660271) - 157G/666PA hitting, 166.0IP pitching
#   CANDIDATE: Willians Astudillo (MLBID: 553902) - hitting (21G/55PA, need 20G/60PA); pitching (2.0IP, need 20IP)
#   CANDIDATE: Josh Harrison (MLBID: 543281) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Luis González (MLBID: 670768) - pitching (6.1IP, need 20IP)
#   CANDIDATE: Ehire Adrianza (MLBID: 501303) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Brett Phillips (MLBID: 621433) - pitching (4.0IP, need 20IP)
#   CANDIDATE: Charlie Culberson (MLBID: 518586) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Kody Clemens (MLBID: 665019) - pitching (7.0IP, need 20IP)
#   CANDIDATE: Kevin Plawecki (MLBID: 608700) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Randal Grichuk (MLBID: 545341) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Donovan Walton (MLBID: 622268) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Matt Reynolds (MLBID: 608703) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Yolmer Sánchez (MLBID: 570560) - hitting (17G/44PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Nick Maton (MLBID: 665155) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Frank Schwindel (MLBID: 643524) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Wil Myers (MLBID: 571976) - pitching (3.2IP, need 20IP)
#   CANDIDATE: Tucker Barnhart (MLBID: 571466) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Darin Ruf (MLBID: 573131) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Alcides Escobar (MLBID: 444876) - pitching (1.2IP, need 20IP)
#   CANDIDATE: Chad Pinder (MLBID: 640461) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Ryan McKenna (MLBID: 663630) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Jace Peterson (MLBID: 607054) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Nicky Lopez (MLBID: 670032) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Sandy León (MLBID: 506702) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Dee Strange-Gordon (MLBID: 543829) - hitting (23G/59PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Carson Kelly (MLBID: 608348) - pitching (4.2IP, need 20IP)
#   CANDIDATE: Alejo Lopez (MLBID: 664670) - pitching (2.2IP, need 20IP)
#   CANDIDATE: Ildemaro Vargas (MLBID: 545121) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Andrelton Simmons (MLBID: 592743) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Chris Owings (MLBID: 572008) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Hanser Alberto (MLBID: 593643) - pitching (11.0IP, need 20IP)
#   CANDIDATE: Victor Caratini (MLBID: 605170) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Christian Bethancourt (MLBID: 542194) - pitching (4.0IP, need 20IP)
#   CANDIDATE: Josh VanMeter (MLBID: 642165) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Nick Gordon (MLBID: 624503) - pitching (3.2IP, need 20IP)
#   CANDIDATE: Mike Brosseau (MLBID: 670712) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Jackie Bradley Jr. (MLBID: 598265) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Sheldon Neuse (MLBID: 641914) - pitching (3.2IP, need 20IP)
#   CANDIDATE: Hunter Dozier (MLBID: 641531) - pitching (1.0IP, need 20IP)
#
# Analyzing 2023 season...
#   Found 56 MLBIDs appearing in both hitting and pitching data
#   CANDIDATE: Nate Eaton (MLBID: 681987) - hitting (28G/56PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Miguel Rojas (MLBID: 500743) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Luke Maile (MLBID: 571912) - pitching (4.1IP, need 20IP)
#   CANDIDATE: Eduardo Escobar (MLBID: 500871) - pitching (3.2IP, need 20IP)
#   CANDIDATE: Austin Hedges (MLBID: 595978) - pitching (3.2IP, need 20IP)
#   CANDIDATE: Josh Rojas (MLBID: 668942) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Zack Short (MLBID: 670097) - pitching (6.0IP, need 20IP)
#   CANDIDATE: Lane Thomas (MLBID: 657041) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Brett Wisely (MLBID: 689172) - pitching (1.0IP, need 20IP)
#   CANDIDATE: James McCann (MLBID: 543510) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Bligh Madris (MLBID: 676632) - hitting (12G/30PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: René Pinto (MLBID: 650907) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jordan Luplow (MLBID: 656669) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Matt Duffy (MLBID: 622110) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Ernie Clement (MLBID: 676391) - hitting (30G/52PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Mike Ford (MLBID: 645801) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Harold Castro (MLBID: 605612) - pitching (2.0IP, need 20IP)
#   QUALIFIED: Shohei Ohtani (MLBID: 660271) - 135G/599PA hitting, 132.0IP pitching
#   CANDIDATE: Josh Harrison (MLBID: 543281) - pitching (1.2IP, need 20IP)
#   CANDIDATE: Brad Miller (MLBID: 543543) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Kody Clemens (MLBID: 665019) - pitching (2.2IP, need 20IP)
#   CANDIDATE: Jason Vosler (MLBID: 613564) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Isiah Kiner-Falefa (MLBID: 643396) - pitching (4.0IP, need 20IP)
#   CANDIDATE: Jose Herrera (MLBID: 645444) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Danny Mendick (MLBID: 664901) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Tucker Barnhart (MLBID: 571466) - pitching (4.0IP, need 20IP)
#   CANDIDATE: Zach McKinstry (MLBID: 656716) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Martín Maldonado (MLBID: 455117) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Ryan McKenna (MLBID: 663630) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jace Peterson (MLBID: 607054) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Nicky Lopez (MLBID: 670032) - pitching (2.1IP, need 20IP)
#   CANDIDATE: Sandy León (MLBID: 506702) - hitting (22G/44PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: David Fry (MLBID: 681807) - pitching (5.0IP, need 20IP)
#   CANDIDATE: Rowdy Tellez (MLBID: 642133) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Brandon Crawford (MLBID: 543063) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Luke Raley (MLBID: 670042) - pitching (2.2IP, need 20IP)
#   CANDIDATE: Carson Kelly (MLBID: 608348) - pitching (2.2IP, need 20IP)
#   CANDIDATE: Alan Trejo (MLBID: 676701) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Ildemaro Vargas (MLBID: 545121) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Josh Donaldson (MLBID: 518626) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jake Lamb (MLBID: 571875) - hitting (19G/54PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Matt Beaty (MLBID: 607461) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Pablo Reyes (MLBID: 622569) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Jonathan Schoop (MLBID: 570731) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Hanser Alberto (MLBID: 593643) - pitching (1.2IP, need 20IP)
#   CANDIDATE: Luis Guillorme (MLBID: 641645) - pitching (1.0IP, need 20IP)
#   CANDIDATE: David Villar (MLBID: 681584) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jacob Stallings (MLBID: 607732) - pitching (8.0IP, need 20IP)
#   CANDIDATE: Brandon Dixon (MLBID: 641525) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Mike Brosseau (MLBID: 670712) - pitching (2.1IP, need 20IP)
#   CANDIDATE: Willi Castro (MLBID: 650489) - pitching (2.1IP, need 20IP)
#   CANDIDATE: Alec Burleson (MLBID: 676475) - pitching (1.2IP, need 20IP)
#
# Analyzing 2024 season...
#   Found 46 MLBIDs appearing in both hitting and pitching data
#   CANDIDATE: Andrew Knizner (MLBID: 668800) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Emmanuel Rivera (MLBID: 656896) - pitching (4.0IP, need 20IP)
#   CANDIDATE: Miguel Rojas (MLBID: 500743) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Luke Maile (MLBID: 571912) - pitching (3.2IP, need 20IP)
#   CANDIDATE: Kyle Farmer (MLBID: 571657) - pitching (4.0IP, need 20IP)
#   CANDIDATE: Austin Hedges (MLBID: 595978) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Michael Stefanic (MLBID: 683021) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Josh Rojas (MLBID: 668942) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Garrett Stubbs (MLBID: 596117) - pitching (4.0IP, need 20IP)
#   CANDIDATE: James McCann (MLBID: 543510) - pitching (1.0IP, need 20IP)
#   CANDIDATE: David Bote (MLBID: 623520) - hitting (37G/48PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Matt Wallner (MLBID: 670242) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Vidal Bruján (MLBID: 660644) - pitching (1.2IP, need 20IP)
#   CANDIDATE: Tyler Fitzgerald (MLBID: 666149) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Dominic Smith (MLBID: 642086) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Ernie Clement (MLBID: 676391) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Weston Wilson (MLBID: 642215) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Cole Tucker (MLBID: 657061) - hitting (25G/57PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Nick Loftin (MLBID: 679845) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jose Trevino (MLBID: 624431) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Ben Rortvedt (MLBID: 666163) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Kody Clemens (MLBID: 665019) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jake Bauers (MLBID: 641343) - pitching (4.0IP, need 20IP)
#   CANDIDATE: Isiah Kiner-Falefa (MLBID: 643396) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Danny Mendick (MLBID: 664901) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Aaron Hicks (MLBID: 543305) - hitting (18G/63PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Tucker Barnhart (MLBID: 571466) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Zach McKinstry (MLBID: 656716) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Mike Yastrzemski (MLBID: 573262) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Pavin Smith (MLBID: 656976) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Rowdy Tellez (MLBID: 642133) - pitching (2.2IP, need 20IP)
#   CANDIDATE: Brandon Crawford (MLBID: 543063) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Luke Williams (MLBID: 663897) - hitting (37G/52PA, need 20G/60PA); pitching (4.0IP, need 20IP)
#   CANDIDATE: David Hensley (MLBID: 682073) - hitting (23G/58PA, need 20G/60PA); pitching (2.0IP, need 20IP)
#   CANDIDATE: Ildemaro Vargas (MLBID: 545121) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Pablo Reyes (MLBID: 622569) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Leo Rivas (MLBID: 660844) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Luis Guillorme (MLBID: 641645) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Willi Castro (MLBID: 650489) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Garrett Hampson (MLBID: 641658) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Enrique Hernández (MLBID: 571771) - pitching (4.1IP, need 20IP)
#
# === FINAL RESULTS ===
# Qualified two-way players: 4
# Total candidates analyzed: 359
#
# QUALIFIED TWO-WAY PLAYERS:
#   Shohei Ohtani (2018): 2.7 hitting WAR + 1.1 pitching WAR = 3.8 total WAR
#   Shohei Ohtani (2021): 5.0 hitting WAR + 3.0 pitching WAR = 8.0 total WAR
#   Shohei Ohtani (2022): 3.6 hitting WAR + 5.6 pitching WAR = 9.2 total WAR
#   Shohei Ohtani (2023): 6.6 hitting WAR + 2.3 pitching WAR = 8.9 total WAR
# === DETAILED TWO-WAY PLAYER CANDIDATE ANALYSIS ===
# === COMPREHENSIVE TWO-WAY PLAYER ANALYSIS ===
# Using MLB criteria: 20+ IP pitching AND 20+ games/60+ PA hitting
# Loading comprehensive FanGraphs and BP data...
# Loaded cached comprehensive FanGraphs data:
#   Hitters: 5757 player-seasons
#   Pitchers: 7230 player-seasons
#   Defensive: 12537 player-seasons
# LOADING BP DATA WITH FIXED DERIVED STATISTICS
# ============================================================
#
# Processing BP Hitter Data:
#    Calculating derived statistics for 2016 data...
#       DATA: K%: 633/633 records have valid values
#       DATA: BB%: 633/633 records have valid values
#    SUCCESS 2016: 633 records loaded
#    Calculating derived statistics for 2017 data...
#       DATA: K%: 623/623 records have valid values
#       DATA: BB%: 623/623 records have valid values
#    SUCCESS 2017: 623 records loaded
#    Calculating derived statistics for 2018 data...
#       DATA: K%: 627/627 records have valid values
#       DATA: BB%: 627/627 records have valid values
#    SUCCESS 2018: 627 records loaded
#    Calculating derived statistics for 2019 data...
#       DATA: K%: 990/990 records have valid values
#       DATA: BB%: 990/990 records have valid values
#    SUCCESS 2019: 990 records loaded
#    OK: 2020 data already has K% and BB% - no calculation needed
#    SUCCESS 2020: 581 records loaded
#    OK: 2021 data already has K% and BB% - no calculation needed
#    SUCCESS 2021: 1049 records loaded
#    OK: 2022 data already has K% and BB% - no calculation needed
#    SUCCESS 2022: 693 records loaded
#    OK: 2023 data already has K% and BB% - no calculation needed
#    SUCCESS 2023: 656 records loaded
#    OK: 2024 data already has K% and BB% - no calculation needed
#    SUCCESS 2024: 651 records loaded
#
# Processing BP Pitcher Data:
#    Calculating derived statistics for 2016 data...
#       DATA: K%: 742/742 records have valid values
#       DATA: BB%: 742/742 records have valid values
#    SUCCESS 2016: 742 records loaded
#    Calculating derived statistics for 2017 data...
#       DATA: K%: 755/755 records have valid values
#       DATA: BB%: 755/755 records have valid values
#    SUCCESS 2017: 755 records loaded
#    Calculating derived statistics for 2018 data...
#       DATA: K%: 799/799 records have valid values
#       DATA: BB%: 799/799 records have valid values
#    SUCCESS 2018: 799 records loaded
#    Calculating derived statistics for 2019 data...
#       DATA: K%: 831/831 records have valid values
#       DATA: BB%: 831/831 records have valid values
#    SUCCESS 2019: 831 records loaded
#    OK: 2020 data already has K% and BB% - no calculation needed
#    SUCCESS 2020: 735 records loaded
#    OK: 2021 data already has K% and BB% - no calculation needed
#    SUCCESS 2021: 909 records loaded
#    OK: 2022 data already has K% and BB% - no calculation needed
#    SUCCESS 2022: 871 records loaded
#    OK: 2023 data already has K% and BB% - no calculation needed
#    SUCCESS 2023: 863 records loaded
#    OK: 2024 data already has K% and BB% - no calculation needed
#    SUCCESS 2024: 840 records loaded
#
# Combined Hitter Data: 6503 total records
#    K% coverage: 100.0%
#    BB% coverage: 100.0%
#
# Combined Pitcher Data: 7345 total records
#    K% coverage: 100.0%
#    BB% coverage: 100.0%
#
# SUCCESS: BP DATA LOADING WITH DERIVED STATISTICS COMPLETE!
#
# Analyzing 2016 season...
#   Found 18 MLBIDs appearing in both hitting and pitching data
#   CANDIDATE: JB Shuck (MLBID: 543776) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Rubén Tejada (MLBID: 514913) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Tyler Holt (MLBID: 534627) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jared Hoying (MLBID: 592419) - hitting (39G/49PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Eduardo Escobar (MLBID: 500871) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Miguel Montero (MLBID: 471083) - pitching (1.1IP, need 20IP)
# ...
#   CANDIDATE: Ryan McKenna (MLBID: 663630) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jace Peterson (MLBID: 607054) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Nicky Lopez (MLBID: 670032) - pitching (2.1IP, need 20IP)
#   CANDIDATE: Sandy León (MLBID: 506702) - hitting (22G/44PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: David Fry (MLBID: 681807) - pitching (5.0IP, need 20IP)
#   CANDIDATE: Rowdy Tellez (MLBID: 642133) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Brandon Crawford (MLBID: 543063) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Luke Raley (MLBID: 670042) - pitching (2.2IP, need 20IP)
#   CANDIDATE: Carson Kelly (MLBID: 608348) - pitching (2.2IP, need 20IP)
#   CANDIDATE: Alan Trejo (MLBID: 676701) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Ildemaro Vargas (MLBID: 545121) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Josh Donaldson (MLBID: 518626) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jake Lamb (MLBID: 571875) - hitting (19G/54PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Matt Beaty (MLBID: 607461) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Pablo Reyes (MLBID: 622569) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Jonathan Schoop (MLBID: 570731) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Hanser Alberto (MLBID: 593643) - pitching (1.2IP, need 20IP)
#   CANDIDATE: Luis Guillorme (MLBID: 641645) - pitching (1.0IP, need 20IP)
#   CANDIDATE: David Villar (MLBID: 681584) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jacob Stallings (MLBID: 607732) - pitching (8.0IP, need 20IP)
#   CANDIDATE: Brandon Dixon (MLBID: 641525) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Mike Brosseau (MLBID: 670712) - pitching (2.1IP, need 20IP)
#   CANDIDATE: Willi Castro (MLBID: 650489) - pitching (2.1IP, need 20IP)
#   CANDIDATE: Alec Burleson (MLBID: 676475) - pitching (1.2IP, need 20IP)
#
# Analyzing 2024 season...
#   Found 46 MLBIDs appearing in both hitting and pitching data
#   CANDIDATE: Andrew Knizner (MLBID: 668800) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Emmanuel Rivera (MLBID: 656896) - pitching (4.0IP, need 20IP)
#   CANDIDATE: Miguel Rojas (MLBID: 500743) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Luke Maile (MLBID: 571912) - pitching (3.2IP, need 20IP)
#   CANDIDATE: Kyle Farmer (MLBID: 571657) - pitching (4.0IP, need 20IP)
#   CANDIDATE: Austin Hedges (MLBID: 595978) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Michael Stefanic (MLBID: 683021) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Josh Rojas (MLBID: 668942) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Garrett Stubbs (MLBID: 596117) - pitching (4.0IP, need 20IP)
#   CANDIDATE: James McCann (MLBID: 543510) - pitching (1.0IP, need 20IP)
#   CANDIDATE: David Bote (MLBID: 623520) - hitting (37G/48PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Matt Wallner (MLBID: 670242) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Vidal Bruján (MLBID: 660644) - pitching (1.2IP, need 20IP)
#   CANDIDATE: Tyler Fitzgerald (MLBID: 666149) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Dominic Smith (MLBID: 642086) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Ernie Clement (MLBID: 676391) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Weston Wilson (MLBID: 642215) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Cole Tucker (MLBID: 657061) - hitting (25G/57PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Nick Loftin (MLBID: 679845) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jose Trevino (MLBID: 624431) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Ben Rortvedt (MLBID: 666163) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Kody Clemens (MLBID: 665019) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Jake Bauers (MLBID: 641343) - pitching (4.0IP, need 20IP)
#   CANDIDATE: Isiah Kiner-Falefa (MLBID: 643396) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Danny Mendick (MLBID: 664901) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Aaron Hicks (MLBID: 543305) - hitting (18G/63PA, need 20G/60PA); pitching (1.0IP, need 20IP)
#   CANDIDATE: Tucker Barnhart (MLBID: 571466) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Zach McKinstry (MLBID: 656716) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Mike Yastrzemski (MLBID: 573262) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Pavin Smith (MLBID: 656976) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Rowdy Tellez (MLBID: 642133) - pitching (2.2IP, need 20IP)
#   CANDIDATE: Brandon Crawford (MLBID: 543063) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Luke Williams (MLBID: 663897) - hitting (37G/52PA, need 20G/60PA); pitching (4.0IP, need 20IP)
#   CANDIDATE: David Hensley (MLBID: 682073) - hitting (23G/58PA, need 20G/60PA); pitching (2.0IP, need 20IP)
#   CANDIDATE: Ildemaro Vargas (MLBID: 545121) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Pablo Reyes (MLBID: 622569) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Leo Rivas (MLBID: 660844) - pitching (2.0IP, need 20IP)
#   CANDIDATE: Luis Guillorme (MLBID: 641645) - pitching (3.0IP, need 20IP)
#   CANDIDATE: Willi Castro (MLBID: 650489) - pitching (1.1IP, need 20IP)
#   CANDIDATE: Garrett Hampson (MLBID: 641658) - pitching (1.0IP, need 20IP)
#   CANDIDATE: Enrique Hernández (MLBID: 571771) - pitching (4.1IP, need 20IP)
#
# === FINAL RESULTS ===
# Qualified two-way players: 4
# Total candidates analyzed: 359
#
# QUALIFIED TWO-WAY PLAYERS:
#   Shohei Ohtani (2018): 2.7 hitting WAR + 1.1 pitching WAR = 3.8 total WAR
#   Shohei Ohtani (2021): 5.0 hitting WAR + 3.0 pitching WAR = 8.0 total WAR
#   Shohei Ohtani (2022): 3.6 hitting WAR + 5.6 pitching WAR = 9.2 total WAR
#   Shohei Ohtani (2023): 6.6 hitting WAR + 2.3 pitching WAR = 8.9 total WAR
#   EMERGENCY: Miguel Montero (MLBID: 471083) (2016) - 86G/284PA hitting, 1.1IP pitching
#   EMERGENCY: Mitch Moreland (MLBID: 519048) (2017) - 149G/576PA hitting, 1.0IP pitching
#   EMERGENCY: Scooter Gennett (MLBID: 571697) (2017) - 141G/497PA hitting, 1.0IP pitching
#   EMERGENCY: Jedd Gyorko (MLBID: 576397) (2018) - 125G/402PA hitting, 1.0IP pitching
#   EMERGENCY: Jeff Mathis (MLBID: 425772) (2018) - 69G/218PA hitting, 1.0IP pitching
#   EMERGENCY: Daniel Robertson (MLBID: 621002) (2018) - 88G/340PA hitting, 1.0IP pitching
#   EMERGENCY: Daniel Descalso (MLBID: 518614) (2018) - 138G/423PA hitting, 3.1IP pitching
#   EMERGENCY: Ian Happ (MLBID: 664023) (2018) - 142G/462PA hitting, 1.0IP pitching
#   EMERGENCY: Kendrys Morales (MLBID: 434778) (2018) - 130G/471PA hitting, 1.0IP pitching
#   EMERGENCY: Brian Dozier (MLBID: 572821) (2019) - 135G/482PA hitting, 1.0IP pitching
#   EMERGENCY: Ian Desmond (MLBID: 435622) (2019) - 140G/482PA hitting, 1.0IP pitching
#   EMERGENCY: Russell Martin (MLBID: 431145) (2019) - 83G/249PA hitting, 4.0IP pitching
#   EMERGENCY: Alex Gordon (MLBID: 460086) (2019) - 150G/633PA hitting, 2.1IP pitching
#   EMERGENCY: Kevin Plawecki (MLBID: 608700) (2019) - 60G/174PA hitting, 2.0IP pitching
#   EMERGENCY: Kendrys Morales (MLBID: 434778) (2019) - 53G/201PA hitting, 1.0IP pitching
#   EMERGENCY: Alex Avila (MLBID: 488671) (2019) - 63G/201PA hitting, 2.0IP pitching
#   EMERGENCY: Hanser Alberto (MLBID: 593643) (2019) - 139G/550PA hitting, 1.0IP pitching
#   EMERGENCY: Victor Caratini (MLBID: 605170) (2019) - 95G/279PA hitting, 2.0IP pitching
#   EMERGENCY: Jacob Stallings (MLBID: 607732) (2019) - 71G/210PA hitting, 1.0IP pitching
#   EMERGENCY: Justin Turner (MLBID: 457759) (2021) - 151G/612PA hitting, 1.0IP pitching
#   EMERGENCY: David Peralta (MLBID: 444482) (2021) - 150G/538PA hitting, 1.0IP pitching
#   EMERGENCY: Darin Ruf (MLBID: 573131) (2021) - 117G/312PA hitting, 1.0IP pitching
#   EMERGENCY: Whit Merrifield (MLBID: 593160) (2022) - 139G/550PA hitting, 1.0IP pitching
#   EMERGENCY: Albert Pujols (MLBID: 405395) (2022) - 109G/351PA hitting, 1.0IP pitching
#   EMERGENCY: Michael A. Taylor (MLBID: 572191) (2022) - 124G/456PA hitting, 2.0IP pitching
#   EMERGENCY: Orlando Arcia (MLBID: 606115) (2022) - 68G/234PA hitting, 1.0IP pitching
#   EMERGENCY: Randal Grichuk (MLBID: 545341) (2022) - 141G/538PA hitting, 1.0IP pitching
#   EMERGENCY: Victor Caratini (MLBID: 605170) (2022) - 96G/314PA hitting, 1.0IP pitching
#   EMERGENCY: Christian Bethancourt (MLBID: 542194) (2022) - 101G/333PA hitting, 4.0IP pitching
#   EMERGENCY: Nick Gordon (MLBID: 624503) (2022) - 138G/443PA hitting, 3.2IP pitching
#   EMERGENCY: Miguel Rojas (MLBID: 500743) (2023) - 125G/423PA hitting, 3.0IP pitching
#   EMERGENCY: Austin Hedges (MLBID: 595978) (2023) - 82G/212PA hitting, 3.2IP pitching
#   EMERGENCY: Lane Thomas (MLBID: 657041) (2023) - 157G/682PA hitting, 1.0IP pitching
#   EMERGENCY: Zach McKinstry (MLBID: 656716) (2023) - 148G/518PA hitting, 1.0IP pitching
#   EMERGENCY: Martín Maldonado (MLBID: 455117) (2023) - 117G/407PA hitting, 1.0IP pitching
#   EMERGENCY: Jace Peterson (MLBID: 607054) (2023) - 134G/430PA hitting, 2.0IP pitching
#   EMERGENCY: Luke Raley (MLBID: 670042) (2023) - 118G/406PA hitting, 2.2IP pitching
#   EMERGENCY: Ildemaro Vargas (MLBID: 545121) (2023) - 86G/286PA hitting, 2.0IP pitching
#   EMERGENCY: Willi Castro (MLBID: 650489) (2023) - 124G/409PA hitting, 2.1IP pitching
#   EMERGENCY: Miguel Rojas (MLBID: 500743) (2024) - 103G/337PA hitting, 1.0IP pitching
#   EMERGENCY: Josh Rojas (MLBID: 668942) (2024) - 143G/476PA hitting, 2.0IP pitching
#   EMERGENCY: Ernie Clement (MLBID: 676391) (2024) - 139G/452PA hitting, 1.0IP pitching
#   EMERGENCY: Jose Trevino (MLBID: 624431) (2024) - 74G/234PA hitting, 2.0IP pitching
#   EMERGENCY: Isiah Kiner-Falefa (MLBID: 643396) (2024) - 133G/496PA hitting, 2.0IP pitching
#   EMERGENCY: Mike Yastrzemski (MLBID: 573262) (2024) - 140G/474PA hitting, 1.0IP pitching
#   EMERGENCY: Rowdy Tellez (MLBID: 642133) (2024) - 132G/421PA hitting, 2.2IP pitching
#   EMERGENCY: Willi Castro (MLBID: 650489) (2024) - 158G/635PA hitting, 1.1IP pitching
#
# Filtered 47 emergency pitching appearances
# Identified 312 legitimate dual-role players
#
# === FINAL SUMMARY ===
# Qualified two-way players (MLB criteria): 4
# Emergency pitching filtered: 47
# Near misses: 0
# Years analyzed: 9
#
# QUALIFIED PLAYERS:
#   660271 (2018): 3.8 total WAR (FG), 1.0 total WARP (BP)
#   660271 (2021): 8.0 total WAR (FG), 11.1 total WARP (BP)
#   660271 (2022): 9.2 total WAR (FG), 10.1 total WARP (BP)
#   660271 (2023): 8.9 total WAR (FG), 10.2 total WARP (BP)
# Filtering position players from WAR pitcher data...
#   Removed 79 emergency/position player pitching records
#   Emergency pitchers filtered: 79
#   Qualified two-way players kept: 0
#   Total legitimate pitcher records: 7158
# Filtering position players from WARP pitcher data...
#   Removed 83 emergency/position player pitching records
#   Emergency pitchers filtered: 83
#   Qualified two-way players kept: 0
#   Total legitimate pitcher records: 7262
# Pitcher data after two-way filtering: 7262 WARP, 7158 WAR
# === CALCULATING ENHANCED BASERUNNING VALUES ===
# Using BP data with Statcast speed adjustments and quintile-based expectations
# === CALCULATING SPEED-ADJUSTED BASERUNNING VALUES ===
# Using BP data with Statcast speed adjustments and quintile-based expectations
# === LOADING BP BASERUNNING DATA (2016-2024) ===
#   2016 baserunning: 1099 players loaded
#   2017 baserunning: 1079 players loaded
#   2018 baserunning: 1107 players loaded
#   2019 baserunning: 1087 players loaded
#   2020 baserunning: 907 players loaded
#   2021 baserunning: 1110 players loaded
#   2022 baserunning: 965 players loaded
#   2023 baserunning: 837 players loaded
#   2024 baserunning: 758 players loaded
#   2016 running speed: 494 players loaded
#   2017 running speed: 489 players loaded
#   2018 running speed: 487 players loaded
#   2019 running speed: 510 players loaded
#   2020 running speed: 351 players loaded
#   2021 running speed: 486 players loaded
#   2022 running speed: 529 players loaded
#   2023 running speed: 518 players loaded
#   2024 running speed: 496 players loaded
# WARNING: 4602 players have baserunning data but no speed data
# WARNING: 13 players have speed data but no baserunning data
# Cached BP baserunning data to C:\Users\nairs\Documents\GithubProjects\oWAR\cache\yearly_bp_baserunning_data.json
# Loaded BP baserunning data: 8949 baserunning player-seasons, 4360 speed player-seasons
# Processing 8949 baserunning records and 4360 speed records
# Speed quintiles (ft/sec): ['21.4', '22.1', '22.6', '23.0', '24.6']
# WARNING: 4602 player-seasons missing speed data (used middle quintile)
# Cached speed-adjusted baserunning values (2457 players)
# SUCCESS: Calculated speed-adjusted baserunning values for 2457 players
# Top 5 speed-adjusted baserunners:
#   Julio Urías: nan
#   Adalberto Mondesi: 2.467
#   Lucas Giolito: nan
#   Germán Márquez: nan
#   Yohander Méndez: nan
# Loaded fielding data: 32562 rows, columns: ['Game', 'Team', 'Stat', 'Data']
# Calculating seasonal outs above average from fielding notes...
# Calculated replacement levels for 6 position-season combinations
# Cached seasonal fielding OAA data (2655 player-seasons)
# === LOADING YEARLY CATCHER FRAMING DATA (2016-2021) ===
#   Missing file: C:\Users\nairs\Documents\GithubProjects\oWAR\MLB Player Data\Statcast_Data\catcher_framing_2016.csv
#   Missing file: C:\Users\nairs\Documents\GithubProjects\oWAR\MLB Player Data\Statcast_Data\catcher_framing_2017.csv
#   Missing file: C:\Users\nairs\Documents\GithubProjects\oWAR\MLB Player Data\Statcast_Data\catcher_framing_2018.csv
#   Missing file: C:\Users\nairs\Documents\GithubProjects\oWAR\MLB Player Data\Statcast_Data\catcher_framing_2019.csv
#   Missing file: C:\Users\nairs\Documents\GithubProjects\oWAR\MLB Player Data\Statcast_Data\catcher_framing_2020.csv
#   Missing file: C:\Users\nairs\Documents\GithubProjects\oWAR\MLB Player Data\Statcast_Data\catcher_framing_2021.csv
# Cached yearly catcher framing data to C:\Users\nairs\Documents\GithubProjects\oWAR\cache\yearly_catcher_framing_data.json
# Loaded yearly catcher framing data: 0 player-seasons
# Loaded framing data for 0 catchers
# Combined defensive metrics: 820 players
#   OAA players: 2655
#   Framing players: 0
# Loading positional adjustments for WAR models...
#   FG defensive data: 19763 records
#   BP fielding data: 11234 player-seasons
# Loaded positional data:
#   FG positions: 19763
#   BP positions: 11234
# Loaded data: 4356 hitter WARP, 7262 pitcher WARP
#               4368 hitter WAR, 7158 pitcher WAR
#               11234 BP positions, 19763 FG positions
# Creating MLBID-based player mappings...
# Creating MLBID-based player mapping...
#   WARP data: 4356 records with valid mlbid
#   WAR data: 4368 records with valid MLBAMID
#   Common MLB IDs: 1258
#   Created 4356 WARP->WAR index mappings
# Creating MLBID-based player mapping...
#   WARP data: 7262 records with valid mlbid
#   WAR data: 7158 records with valid MLBAMID
#   Common MLB IDs: 2193
#   Created 7224 WARP->WAR index mappings
# MLBID mappings created: 4356 hitters, 7224 pitchers
# Merging positional data with offensive stats...
#   Position assignment: 4352/4356 (99.9%)
#   Positional WAR range: -1.521 to 1.508 (mean: -0.091)
# Merging positional data with offensive stats...
#   Position assignment: 4326/4356 (99.3%)
#   Positional WAR range: -1.456 to 1.448 (mean: -0.061)
# Selected WARP features: ['K%', 'BB%', 'AVG', 'OBP', 'SLG', 'Enhanced_Baserunning', 'Enhanced_Defense', 'Positional_WAR'] (from 30 available)
# Selected WAR features: ['K%', 'BB%', 'AVG', 'OBP', 'SLG', 'Enhanced_Baserunning', 'Enhanced_Defense', 'Positional_WAR'] (from 32 available)
#   WARP data: 4356/4356 records with valid WARP values
#   WAR data: 4356/4356 records with valid WAR values
# Merging positional data with offensive stats...
#   Position assignment: 7222/7224 (100.0%)
#   Positional WAR range: -1.250 to 1.250 (mean: -0.010)
# Merging positional data with offensive stats...
#   Position assignment: 7224/7224 (100.0%)
#   Positional WAR range: -1.250 to 1.250 (mean: -0.010)
# Selected WARP features: ['IP', 'BB%', 'K%', 'HR%', 'ERA', 'Enhanced_Baserunning', 'Enhanced_Defense', 'Positional_WAR'] (from 30 available)
# Selected WAR features: ['IP', 'BB/9', 'K/9', 'HR/9', 'ERA', 'Enhanced_Baserunning', 'Enhanced_Defense', 'Positional_WAR'] (from 30 available)
#   WARP data: 7206/7224 records with valid WARP values
#   WAR data: 7224/7224 records with valid WAR values
# ✓ Hitter data loaded: 4 WARP records
# ✓ Hitter data loaded: 4 WAR records
# ✓ Pitcher data loaded: 4 WARP records
# ✓ Pitcher data loaded: 4 WAR records

# %%
# Prepare age curve training data
print("\n1.2: Preparing age curve training data...")

def prepare_age_curve_training_data(hitter_data, pitcher_data):
    """
    Combine hitter and pitcher data for age curve modeling.
    Fixed to properly handle mlbid instead of incorrectly using player names.
    """
    training_datasets = []
    
    # We need to get the actual mlbid data from the source since temp_modeling doesn't provide it
    # Import the data loading functions from the correct locations
    from shared_modules.bp_derived_stats import load_fixed_bp_data
    from current_season_modules.temp_modeling import load_expanded_fangraphs_data, filter_pitchers_from_hitting_data
    
    print("Loading source data to get proper mlbid information...")
    
    # Load the source datasets that contain mlbid
    try:
        hitter_warp_full, pitcher_warp_full = load_fixed_bp_data()
        hitter_war_full = load_expanded_fangraphs_data()
        hitter_war_full = filter_pitchers_from_hitting_data(hitter_war_full, 'war', 'Year')
        
        print(f"✓ Source data loaded: {len(hitter_warp_full)} WARP hitters, {len(pitcher_warp_full)} WARP pitchers, {len(hitter_war_full)} WAR hitters")
        
    except Exception as e:
        print(f"⚠ Could not load source data: {e}")
        print("Using fallback approach with player names...")
        
        # Fallback: use player names for matching (less reliable)
        return prepare_age_curve_training_data_fallback(hitter_data, pitcher_data)
    
    # Process hitter data
    if hitter_data:
        for data_type in ['warp', 'war']:
            if data_type in hitter_data and hitter_data[data_type] is not None:
                data = hitter_data[data_type]
                
                # Get the corresponding source dataset
                if data_type == 'warp':
                    source_df = hitter_warp_full
                    id_col = 'mlbid'
                    year_col = 'Season'
                else:  # war
                    source_df = hitter_war_full  
                    id_col = 'MLBAMID'
                    year_col = 'Year'
                
                # Create mapping from names to get mlbid
                name_to_mlbid = {}
                for _, row in source_df.iterrows():
                    if pd.notna(row.get('Name')) and pd.notna(row.get(id_col)):
                        name_to_mlbid[row['Name']] = row[id_col]
                
                # Create DataFrame with proper mlbid
                mlbids = []
                for name in data['names']:
                    mlbid = name_to_mlbid.get(name, None)
                    mlbids.append(mlbid)
                
                hitter_df = pd.DataFrame({
                    'mlbid': mlbids,
                    'Name': data['names'],
                    'Season': data['years'],
                    'WAR': data['y'],
                    'PlayerType': 'Hitter',
                    'DataSource': data_type.upper()
                })
                
                # Filter out records without mlbid
                hitter_df = hitter_df[hitter_df['mlbid'].notna()].copy()
                
                # Add features as additional columns
                feature_df = pd.DataFrame(data['X'])
                feature_df.columns = [f'feature_{i}' for i in range(len(feature_df.columns))]
                feature_df = feature_df.iloc[:len(hitter_df)].reset_index(drop=True)
                
                combined_df = pd.concat([hitter_df.reset_index(drop=True), feature_df], axis=1)
                training_datasets.append(combined_df)
                
                print(f"✓ Processed {data_type.upper()} hitters: {len(hitter_df)} records with valid mlbid")
    
    # Process pitcher data
    if pitcher_data:
        for data_type in ['warp', 'war']:
            if data_type in pitcher_data and pitcher_data[data_type] is not None:
                data = pitcher_data[data_type]
                
                # Get the corresponding source dataset
                if data_type == 'warp':
                    source_df = pitcher_warp_full
                    id_col = 'mlbid'
                    year_col = 'Season'
                else:  # war
                    # For pitcher WAR, we would need to load pitcher WAR data separately
                    # For now, skip WAR pitchers since we mainly loaded hitter WAR data
                    print(f"⚠ Skipping WAR pitchers - would need separate pitcher WAR dataset")
                    continue
                
                # Create mapping from names to get mlbid
                name_to_mlbid = {}
                for _, row in source_df.iterrows():
                    if pd.notna(row.get('Name')) and pd.notna(row.get(id_col)):
                        name_to_mlbid[row['Name']] = row[id_col]
                
                # Create DataFrame with proper mlbid
                mlbids = []
                for name in data['names']:
                    mlbid = name_to_mlbid.get(name, None)
                    mlbids.append(mlbid)
                
                pitcher_df = pd.DataFrame({
                    'mlbid': mlbids,
                    'Name': data['names'],
                    'Season': data['years'],
                    'WAR': data['y'],
                    'PlayerType': 'Pitcher',
                    'DataSource': data_type.upper()
                })
                
                # Filter out records without mlbid
                pitcher_df = pitcher_df[pitcher_df['mlbid'].notna()].copy()
                
                # Add features as additional columns
                feature_df = pd.DataFrame(data['X'])
                feature_df.columns = [f'feature_{i}' for i in range(len(feature_df.columns))]
                feature_df = feature_df.iloc[:len(pitcher_df)].reset_index(drop=True)
                
                combined_df = pd.concat([pitcher_df.reset_index(drop=True), feature_df], axis=1)
                training_datasets.append(combined_df)
                
                print(f"✓ Processed {data_type.upper()} pitchers: {len(pitcher_df)} records with valid mlbid")
    
    if training_datasets:
        # Combine all datasets
        combined_data = pd.concat(training_datasets, ignore_index=True)
        
        # Add age data
        age_loader = AgeDataLoader()
        combined_data_with_ages = age_loader.merge_ages_with_pipeline(combined_data)
        
        return combined_data_with_ages
    
    return pd.DataFrame()

def prepare_age_curve_training_data_fallback(hitter_data, pitcher_data):
    """
    Fallback function that uses player name matching instead of mlbid.
    Less reliable but works when mlbid data is not available.
    """
    print("Using fallback approach with name-based matching...")
    
    training_datasets = []
    
    # Process hitter data
    if hitter_data:
        for data_type in ['warp', 'war']:
            if data_type in hitter_data and hitter_data[data_type] is not None:
                data = hitter_data[data_type]
                
                # Use player names as identifiers (less reliable)
                hitter_df = pd.DataFrame({
                    'Name': data['names'],
                    'Season': data['years'],
                    'WAR': data['y'],
                    'PlayerType': 'Hitter',
                    'DataSource': data_type.upper()
                })
                
                # Add features as additional columns
                feature_df = pd.DataFrame(data['X'])
                feature_df.columns = [f'feature_{i}' for i in range(len(feature_df.columns))]
                
                combined_df = pd.concat([hitter_df, feature_df], axis=1)
                training_datasets.append(combined_df)
    
    # Process pitcher data
    if pitcher_data:
        for data_type in ['warp', 'war']:
            if data_type in pitcher_data and pitcher_data[data_type] is not None:
                data = pitcher_data[data_type]
                
                pitcher_df = pd.DataFrame({
                    'Name': data['names'],
                    'Season': data['years'],
                    'WAR': data['y'],
                    'PlayerType': 'Pitcher',
                    'DataSource': data_type.upper()
                })
                
                # Add features as additional columns
                feature_df = pd.DataFrame(data['X'])
                feature_df.columns = [f'feature_{i}' for i in range(len(feature_df.columns))]
                
                combined_df = pd.concat([pitcher_df, feature_df], axis=1)
                training_datasets.append(combined_df)
    
    if training_datasets:
        # Combine all datasets
        combined_data = pd.concat(training_datasets, ignore_index=True)
        
        # For name-based matching, we'll need to modify the age loader
        # or create a name-based age matching approach
        print("⚠ Name-based age matching not yet implemented")
        print("⚠ Age data will not be available with this fallback approach")
        
        return combined_data
    
    return pd.DataFrame()

# Prepare training data
age_training_data = prepare_age_curve_training_data(hitter_data, pitcher_data)

print(f"✓ Age curve training data prepared: {len(age_training_data)} total records")

if len(age_training_data) > 0:
    print(f"✓ Age coverage: {age_training_data['Age'].notna().sum()}/{len(age_training_data)} records ({age_training_data['Age'].notna().sum()/len(age_training_data)*100:.1f}%)")
    print(f"✓ Age range: {age_training_data['Age'].min():.0f} - {age_training_data['Age'].max():.0f} years")
    print(f"✓ Season range: {age_training_data['Season'].min()} - {age_training_data['Season'].max()}")
    print(f"✓ Hitters: {len(age_training_data[age_training_data['PlayerType'] == 'Hitter'])}, Pitchers: {len(age_training_data[age_training_data['PlayerType'] == 'Pitcher'])}")
    
    # Show mlbid coverage
    if 'mlbid' in age_training_data.columns:
        mlbid_coverage = age_training_data['mlbid'].notna().sum()
        print(f"✓ MLBID coverage: {mlbid_coverage}/{len(age_training_data)} records ({mlbid_coverage/len(age_training_data)*100:.1f}%)")
else:
    print("⚠ No training data available for age curve modeling")
# Out:
# 1.2: Preparing age curve training data...
# Loading source data to get proper mlbid information...
# LOADING BP DATA WITH FIXED DERIVED STATISTICS
# ============================================================
#
# Processing BP Hitter Data:
#    Calculating derived statistics for 2016 data...
#       DATA: K%: 633/633 records have valid values
#       DATA: BB%: 633/633 records have valid values
#    SUCCESS 2016: 633 records loaded
#    Calculating derived statistics for 2017 data...
#       DATA: K%: 623/623 records have valid values
#       DATA: BB%: 623/623 records have valid values
#    SUCCESS 2017: 623 records loaded
#    Calculating derived statistics for 2018 data...
#       DATA: K%: 627/627 records have valid values
#       DATA: BB%: 627/627 records have valid values
#    SUCCESS 2018: 627 records loaded
#    Calculating derived statistics for 2019 data...
#       DATA: K%: 990/990 records have valid values
#       DATA: BB%: 990/990 records have valid values
#    SUCCESS 2019: 990 records loaded
#    OK: 2020 data already has K% and BB% - no calculation needed
#    SUCCESS 2020: 581 records loaded
#    OK: 2021 data already has K% and BB% - no calculation needed
#    SUCCESS 2021: 1049 records loaded
#    OK: 2022 data already has K% and BB% - no calculation needed
#    SUCCESS 2022: 693 records loaded
#    OK: 2023 data already has K% and BB% - no calculation needed
#    SUCCESS 2023: 656 records loaded
#    OK: 2024 data already has K% and BB% - no calculation needed
#    SUCCESS 2024: 651 records loaded
#
# Processing BP Pitcher Data:
#    Calculating derived statistics for 2016 data...
#       DATA: K%: 742/742 records have valid values
#       DATA: BB%: 742/742 records have valid values
#    SUCCESS 2016: 742 records loaded
#    Calculating derived statistics for 2017 data...
#       DATA: K%: 755/755 records have valid values
#       DATA: BB%: 755/755 records have valid values
#    SUCCESS 2017: 755 records loaded
#    Calculating derived statistics for 2018 data...
#       DATA: K%: 799/799 records have valid values
#       DATA: BB%: 799/799 records have valid values
#    SUCCESS 2018: 799 records loaded
#    Calculating derived statistics for 2019 data...
#       DATA: K%: 831/831 records have valid values
#       DATA: BB%: 831/831 records have valid values
#    SUCCESS 2019: 831 records loaded
#    OK: 2020 data already has K% and BB% - no calculation needed
#    SUCCESS 2020: 735 records loaded
#    OK: 2021 data already has K% and BB% - no calculation needed
#    SUCCESS 2021: 909 records loaded
#    OK: 2022 data already has K% and BB% - no calculation needed
#    SUCCESS 2022: 871 records loaded
#    OK: 2023 data already has K% and BB% - no calculation needed
#    SUCCESS 2023: 863 records loaded
#    OK: 2024 data already has K% and BB% - no calculation needed
#    SUCCESS 2024: 840 records loaded
#
# Combined Hitter Data: 6503 total records
#    K% coverage: 100.0%
#    BB% coverage: 100.0%
#
# Combined Pitcher Data: 7345 total records
#    K% coverage: 100.0%
#    BB% coverage: 100.0%
#
# SUCCESS: BP DATA LOADING WITH DERIVED STATISTICS COMPLETE!
# Loading expanded FanGraphs hitter data...
#    SUCCESS 2016: 633 hitter records loaded
#    SUCCESS 2017: 625 hitter records loaded
#    SUCCESS 2018: 629 hitter records loaded
#    SUCCESS 2019: 635 hitter records loaded
#    SUCCESS 2020: 581 hitter records loaded
#    SUCCESS 2021: 661 hitter records loaded
#    SUCCESS 2022: 690 hitter records loaded
#    SUCCESS 2023: 655 hitter records loaded
#    SUCCESS 2024: 651 hitter records loaded
#
# Expanded FanGraphs hitter data: 5760 total records
#    PA range: 0 to 753
#    Players with 0 PA: 15
#    Players with <100 PA: 1830
#    Players with 400+ PA: 1652
# Filtering pitchers from WAR hitting data...
# LOADING BP DATA WITH FIXED DERIVED STATISTICS
# ============================================================
#
# Processing BP Hitter Data:
#    Calculating derived statistics for 2016 data...
#       DATA: K%: 633/633 records have valid values
#       DATA: BB%: 633/633 records have valid values
#    SUCCESS 2016: 633 records loaded
#    Calculating derived statistics for 2017 data...
#       DATA: K%: 623/623 records have valid values
#       DATA: BB%: 623/623 records have valid values
#    SUCCESS 2017: 623 records loaded
#    Calculating derived statistics for 2018 data...
#       DATA: K%: 627/627 records have valid values
#       DATA: BB%: 627/627 records have valid values
#    SUCCESS 2018: 627 records loaded
#    Calculating derived statistics for 2019 data...
#       DATA: K%: 990/990 records have valid values
#       DATA: BB%: 990/990 records have valid values
#    SUCCESS 2019: 990 records loaded
#    OK: 2020 data already has K% and BB% - no calculation needed
#    SUCCESS 2020: 581 records loaded
#    OK: 2021 data already has K% and BB% - no calculation needed
#    SUCCESS 2021: 1049 records loaded
#    OK: 2022 data already has K% and BB% - no calculation needed
#    SUCCESS 2022: 693 records loaded
#    OK: 2023 data already has K% and BB% - no calculation needed
#    SUCCESS 2023: 656 records loaded
#    OK: 2024 data already has K% and BB% - no calculation needed
#    SUCCESS 2024: 651 records loaded
#
# Processing BP Pitcher Data:
#    Calculating derived statistics for 2016 data...
#       DATA: K%: 742/742 records have valid values
#       DATA: BB%: 742/742 records have valid values
#    SUCCESS 2016: 742 records loaded
#    Calculating derived statistics for 2017 data...
#       DATA: K%: 755/755 records have valid values
#       DATA: BB%: 755/755 records have valid values
#    SUCCESS 2017: 755 records loaded
#    Calculating derived statistics for 2018 data...
#       DATA: K%: 799/799 records have valid values
#       DATA: BB%: 799/799 records have valid values
#    SUCCESS 2018: 799 records loaded
#    Calculating derived statistics for 2019 data...
#       DATA: K%: 831/831 records have valid values
#       DATA: BB%: 831/831 records have valid values
#    SUCCESS 2019: 831 records loaded
#    OK: 2020 data already has K% and BB% - no calculation needed
#    SUCCESS 2020: 735 records loaded
#    OK: 2021 data already has K% and BB% - no calculation needed
#    SUCCESS 2021: 909 records loaded
#    OK: 2022 data already has K% and BB% - no calculation needed
#    SUCCESS 2022: 871 records loaded
#    OK: 2023 data already has K% and BB% - no calculation needed
#    SUCCESS 2023: 863 records loaded
#    OK: 2024 data already has K% and BB% - no calculation needed
#    SUCCESS 2024: 840 records loaded
#
# Combined Hitter Data: 6503 total records
#    K% coverage: 100.0%
#    BB% coverage: 100.0%
#
# Combined Pitcher Data: 7345 total records
#    K% coverage: 100.0%
#    BB% coverage: 100.0%
#
# SUCCESS: BP DATA LOADING WITH DERIVED STATISTICS COMPLETE!
#   Found 2267 pitcher names to potentially filter
#   2016: Removed 143 pitchers (pre-2020 rule)
#   2017: Removed 154 pitchers (pre-2020 rule)
#   2018: Removed 170 pitchers (pre-2020 rule)
#   2019: Removed 180 pitchers (pre-2020 rule)
#   2020: Removed 158 pitchers (2020+ rule, two-way logic TBD)
#   2021: Removed 177 pitchers (2020+ rule, two-way logic TBD)
#   2022: Removed 163 pitchers (2020+ rule, two-way logic TBD)
#   2023: Removed 140 pitchers (2020+ rule, two-way logic TBD)
#   2024: Removed 107 pitchers (2020+ rule, two-way logic TBD)
#   WAR hitting data: 5760 -> 4368 records after pitcher filtering
# ✓ Source data loaded: 6503 WARP hitters, 7345 WARP pitchers, 4368 WAR hitters
# ✓ Processed WARP hitters: 4356 records with valid mlbid
# ✓ Processed WAR hitters: 4356 records with valid mlbid
# ✓ Processed WARP pitchers: 7206 records with valid mlbid
# ⚠ Skipping WAR pitchers - would need separate pitcher WAR dataset
# Loading age data from BP files...
# ['bp', 'hitters', '2016.csv']
#    SUCCESS 2016: 633 age records loaded
# ['bp', 'hitters', '2016', 'standard.csv']
#    SUCCESS 2016: 633 age records loaded
# ['bp', 'hitters', '2017.csv']
#    SUCCESS 2017: 623 age records loaded
# ['bp', 'hitters', '2017', 'standard.csv']
#    SUCCESS 2017: 623 age records loaded
# ['bp', 'hitters', '2018.csv']
#    SUCCESS 2018: 627 age records loaded
# ['bp', 'hitters', '2018', 'standard.csv']
#    SUCCESS 2018: 627 age records loaded
# ['bp', 'hitters', '2019.csv']
#    SUCCESS 2019: 990 age records loaded
# ['bp', 'hitters', '2019', 'standard.csv']
#    SUCCESS 2019: 990 age records loaded
# ['bp', 'hitters', '2020.csv']
#    SUCCESS 2020: 581 age records loaded
# ['bp', 'hitters', '2020', 'standard.csv']
#    SUCCESS 2020: 581 age records loaded
# ['bp', 'hitters', '2021.csv']
#    SUCCESS 2021: 1049 age records loaded
# ['bp', 'hitters', '2021', 'standard.csv']
#    SUCCESS 2021: 1049 age records loaded
# ['bp', 'hitters', '2022.csv']
#    SUCCESS 2022: 693 age records loaded
# ['bp', 'hitters', '2022', 'standard.csv']
#    SUCCESS 2022: 693 age records loaded
# ['bp', 'hitters', '2023.csv']
#    SUCCESS 2023: 656 age records loaded
# ['bp', 'hitters', '2023', 'standard.csv']
#    SUCCESS 2023: 656 age records loaded
# ['bp', 'hitters', '2024.csv']
#    SUCCESS 2024: 651 age records loaded
# ['bp', 'hitters', '2024', 'standard.csv']
#    SUCCESS 2024: 651 age records loaded
# Total age data loaded: 13006 records
# Handling 6150 missing ages...
#    Imputed 2340 ages
# Age merge: 21876/25686 records (85.2%)
# ✓ Age curve training data prepared: 25686 total records
# ✓ Age coverage: 21876/25686 records (85.2%)
# ✓ Age range: 19 - 45 years
# ✓ Season range: 2016 - 2024
# ✓ Hitters: 17420, Pitchers: 8266
# ✓ MLBID coverage: 25686/25686 records (100.0%)

# %%
# Add primary position data for age curve modeling
print("\n1.3: Adding positional data for age curve analysis...")

# Load positional adjustments
bp_positions, fg_positions = load_positional_adjustments_for_war_models()

def add_position_data(df, bp_positions, fg_positions):
    """
    Add primary position information to the dataset.
    """
    if len(df) == 0:
        return df
    
    # Try to merge with FanGraphs positions first (comprehensive coverage)
    if len(fg_positions) > 0:
        df_with_pos = df.merge(
            fg_positions[['MLBAMID', 'Season', 'Primary_Position']].rename(columns={'MLBAMID': 'mlbid'}),
            on=['mlbid', 'Season'],
            how='left'
        )
    else:
        df_with_pos = df.copy()
        df_with_pos['Primary_Position'] = None
    
    # Fill missing positions with BP data
    if len(bp_positions) > 0:
        missing_positions = df_with_pos['Primary_Position'].isna()
        if missing_positions.sum() > 0:
            bp_merge = df_with_pos[missing_positions].merge(
                bp_positions[['mlbid', 'Season', 'Primary_Position']],
                on=['mlbid', 'Season'],
                how='left',
                suffixes=('', '_bp')
            )
            df_with_pos.loc[missing_positions, 'Primary_Position'] = bp_merge['Primary_Position_bp'].values
    
    # Default position for missing data
    missing_after_merge = df_with_pos['Primary_Position'].isna()
    if missing_after_merge.sum() > 0:
        # Use player type to assign default position
        df_with_pos.loc[missing_after_merge & (df_with_pos['PlayerType'] == 'Pitcher'), 'Primary_Position'] = 'P'
        df_with_pos.loc[missing_after_merge & (df_with_pos['PlayerType'] == 'Hitter'), 'Primary_Position'] = '1B'
    
    return df_with_pos

# Add position data
age_training_data = add_position_data(age_training_data, bp_positions, fg_positions)

# Show position distribution
if len(age_training_data) > 0:
    position_counts = age_training_data['Primary_Position'].value_counts()
    print(f"✓ Position data added: {age_training_data['Primary_Position'].notna().sum()}/{len(age_training_data)} records")
    print("✓ Position distribution:")
    for pos, count in position_counts.head(10).items():
        print(f"   {pos}: {count}")
else:
    print("⚠ No training data available for age curve modeling")
# Out:
# 1.3: Adding positional data for age curve analysis...
# Loading positional adjustments for WAR models...
#   FG defensive data: 19763 records
#   BP fielding data: 11234 player-seasons
# Loaded positional data:
#   FG positions: 19763
#   BP positions: 11234
# ✓ Position data added: 45435/45435 records
# ✓ Position distribution:
#    P: 8228
#    LF: 6885
#    RF: 6238
#    CF: 5034
#    1B: 4514
#    2B: 4220
#    3B: 4194
#    SS: 3324
#    C: 2798

# %%
# Train the joint age curve model
print("\n1.4: Training joint longitudinal-survival age curve model...")

if len(age_training_data) > 0 and age_training_data['Age'].notna().sum() > 100:
    # Initialize age curve model
    age_curve_model = FutureProjectionAgeCurve(max_projection_years=3)
    
    try:
        # Filter data for training (need complete records)
        training_subset = age_training_data[
            age_training_data['Age'].notna() & 
            age_training_data['Primary_Position'].notna() &
            age_training_data['WAR'].notna() &
            age_training_data['Season'].notna()
        ].copy()
        
        print(f"✓ Training subset: {len(training_subset)} complete records")
        
        if len(training_subset) >= 50:  # Minimum for meaningful training
            # Fit joint model
            age_curve_model.fit_joint_model(training_subset)
            
            # Save model
            model_path = "age_curve_model_system2.pkl"
            age_curve_model.save_model(model_path)
            
            print(f"✓ Joint age curve model fitted and saved to {model_path}")
            model_trained = True
        else:
            print(f"⚠ Insufficient training data ({len(training_subset)} records). Need at least 50.")
            model_trained = False
            age_curve_model = None
            
    except Exception as e:
        print(f"⚠ Model training failed: {e}")
        print("Creating simplified age curve model...")
        
        # Fallback: simple age curve without full joint modeling
        age_curve_model = FutureProjectionAgeCurve(max_projection_years=3)
        model_trained = False
        
else:
    print("⚠ Insufficient age data for model training")
    age_curve_model = None
    model_trained = False

print(f"\nModel Training Status: {'✓ SUCCESS' if model_trained else '⚠ LIMITED FUNCTIONALITY'}")
# Out:
# 1.4: Training joint longitudinal-survival age curve model...
# ✓ Training subset: 41620 complete records
# Fitting joint longitudinal-survival model for future projections...
# Preparing longitudinal data for multi-year WAR prediction...
# Longitudinal data prepared: 39611 training examples, 15 features
# Preparing survival data for retirement risk modeling...
# Survival data prepared: 41620 observations, 1152 retirement events
# Fitting multi-year performance trajectory model...
#    Year 1 projection: R² = 0.038, RMSE = 1.358
#    Year 2 projection: R² = 0.040, RMSE = 1.345
#    Year 3 projection: R² = 0.043, RMSE = 1.327
# Fitting retirement hazard model...
#    Validating survival data: 41620 observations, 1152 events
#    Duration range: 1.0 - 9.0
#    Event rate: 0.028
#    WARNING: Survival model fitting failed: Convergence halted due to matrix inversion problems. Suspicion is high collinearity. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-modelMatrix is singular.
#    Details: Convergence halted due to matrix inversion problems. Suspicion is high collinearity. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-modelMatrix is singular.
#    Attempting simplified survival model...
#    Simplified Cox PH model fitted successfully
# Joint model fitting complete!
# Model saved to age_curve_model_system2.pkl
# ✓ Joint age curve model fitted and saved to age_curve_model_system2.pkl
#
# Model Training Status: ✓ SUCCESS

# %% [markdown]
# ## Section 2: Model Validation and Performance
#
# Cross-validate the joint model using temporal splits and analyze overall performance metrics.

# %%
# Cross-validate the joint model
print("SECTION 2: MODEL VALIDATION AND PERFORMANCE")
print("=" * 50)

if model_trained and age_curve_model is not None:
    print("\n2.1: Running temporal cross-validation...")
    
    try:
        # Initialize validator
        validator = AgeCurveValidator(n_splits=3)  # Fewer splits for faster execution
        
        # Run validation
        validation_results = validator.validate_joint_model(age_curve_model, training_subset)
        
        print("\n✓ Validation Results:")
        for metric, value in validation_results.items():
            if not np.isnan(value):
                print(f"   {metric}: {value:.3f}")
        
        validation_completed = True
        
    except Exception as e:
        print(f"⚠ Validation failed: {e}")
        validation_results = {}
        validation_completed = False
        
else:
    print("\n2.1: Skipping validation - model not trained")
    validation_results = {}
    validation_completed = False
# Out:
# SECTION 2: MODEL VALIDATION AND PERFORMANCE
# ==================================================
#
# 2.1: Running temporal cross-validation...
# Validating joint longitudinal-survival model...
# Creating 3 temporal splits with survival considerations...
#    Split 1: Train 2016-2017, Test 2018-2019
#    Split 2: Train 2016-2019, Test 2020-2021
#    Split 3: Train 2016-2021, Test 2022-2023
#
# Validating split 1/3...
# Fitting joint longitudinal-survival model for future projections...
# Preparing longitudinal data for multi-year WAR prediction...
# Longitudinal data prepared: 14016 training examples, 15 features
# Preparing survival data for retirement risk modeling...
# Survival data prepared: 14925 observations, 909 retirement events
# Fitting multi-year performance trajectory model...
#    Year 1 projection: R² = 0.045, RMSE = 1.615
#    Year 2 projection: R² = 0.052, RMSE = 1.591
#    Year 3 projection: R² = 0.053, RMSE = 1.575
# Fitting retirement hazard model...
#    Validating survival data: 14925 observations, 909 events
#    Duration range: 1.0 - 2.0
#    Event rate: 0.061
#    WARNING: Survival model fitting failed: Convergence halted due to matrix inversion problems. Suspicion is high collinearity. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-modelMatrix is singular.
#    Details: Convergence halted due to matrix inversion problems. Suspicion is high collinearity. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-modelMatrix is singular.
#    Attempting simplified survival model...
#    Simplified Cox PH model fitted successfully
# Joint model fitting complete!
#    Longitudinal R²: -0.007, RMSE: 1.275
#    Survival concordance: 0.700
#
# Validating split 2/3...
# Fitting joint longitudinal-survival model for future projections...
# Preparing longitudinal data for multi-year WAR prediction...
# Longitudinal data prepared: 22089 training examples, 15 features
# Preparing survival data for retirement risk modeling...
# Survival data prepared: 23366 observations, 1277 retirement events
# Fitting multi-year performance trajectory model...
#    Year 1 projection: R² = 0.035, RMSE = 1.506
#    Year 2 projection: R² = 0.039, RMSE = 1.487
#    Year 3 projection: R² = 0.046, RMSE = 1.461
# Fitting retirement hazard model...
#    Validating survival data: 23366 observations, 1277 events
#    Duration range: 1.0 - 4.0
#    Event rate: 0.055
#    WARNING: Survival model fitting failed: Convergence halted due to matrix inversion problems. Suspicion is high collinearity. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-modelMatrix is singular.
#    Details: Convergence halted due to matrix inversion problems. Suspicion is high collinearity. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-modelMatrix is singular.
#    Attempting simplified survival model...
#    Simplified Cox PH model fitted successfully
# Joint model fitting complete!
#    Longitudinal R²: -0.006, RMSE: 1.040
#    Survival concordance: 0.700
#
# Validating split 3/3...
# Fitting joint longitudinal-survival model for future projections...
# Preparing longitudinal data for multi-year WAR prediction...
# Longitudinal data prepared: 28893 training examples, 15 features
# Preparing survival data for retirement risk modeling...
# Survival data prepared: 30479 observations, 1586 retirement events
# Fitting multi-year performance trajectory model...
#    Year 1 projection: R² = 0.037, RMSE = 1.415
#    Year 2 projection: R² = 0.041, RMSE = 1.398
#    Year 3 projection: R² = 0.046, RMSE = 1.376
# Fitting retirement hazard model...
#    Validating survival data: 30479 observations, 1586 events
#    Duration range: 1.0 - 6.0
#    Event rate: 0.052
#    WARNING: Survival model fitting failed: Convergence halted due to matrix inversion problems. Suspicion is high collinearity. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-modelMatrix is singular.
#    Details: Convergence halted due to matrix inversion problems. Suspicion is high collinearity. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-modelMatrix is singular.
#    Attempting simplified survival model...
#    Simplified Cox PH model fitted successfully
# Joint model fitting complete!
#    Longitudinal R²: -0.001, RMSE: 1.170
#    Survival concordance: 0.700
#
# Overall validation results:
#    longitudinal_r2_mean: -0.005
#    longitudinal_r2_std: 0.002
#    longitudinal_rmse_mean: 1.162
#    longitudinal_rmse_std: 0.096
#    survival_concordance_mean: 0.700
#    survival_concordance_std: 0.000
#
# ✓ Validation Results:
#    longitudinal_r2_mean: -0.005
#    longitudinal_r2_std: 0.002
#    longitudinal_rmse_mean: 1.162
#    longitudinal_rmse_std: 0.096
#    survival_concordance_mean: 0.700
#    survival_concordance_std: 0.000

# %%
# Performance visualization
print("\n2.2: Creating performance visualizations...")

if len(age_training_data) > 0:
    # Age distribution analysis
    fig = make_subplots(
        rows=2, cols=2,
        subplot_titles=(
            'Age Distribution by Position',
            'WAR by Age',
            'Career Length Distribution', 
            'Performance by Career Stage'
        ),
        specs=[[{"secondary_y": False}, {"secondary_y": False}],
               [{"secondary_y": False}, {"secondary_y": False}]]
    )
    
    # Age distribution by position
    positions = ['C', 'SS', '2B', '3B', '1B', 'LF', 'CF', 'RF', 'DH', 'P']
    for pos in positions:
        pos_data = age_training_data[age_training_data['Primary_Position'] == pos]
        if len(pos_data) > 0:
            fig.add_trace(
                go.Box(y=pos_data['Age'], name=pos, showlegend=False),
                row=1, col=1
            )
    
    # WAR by age (scatter plot)
    valid_data = age_training_data[age_training_data['Age'].notna() & age_training_data['WAR'].notna()]
    if len(valid_data) > 0:
        fig.add_trace(
            go.Scatter(
                x=valid_data['Age'],
                y=valid_data['WAR'],
                mode='markers',
                opacity=0.6,
                name='WAR vs Age',
                showlegend=False
            ),
            row=1, col=2
        )
    
    # Career length (estimated)
    if 'Season' in age_training_data.columns:
        career_lengths = age_training_data.groupby('Name')['Season'].nunique()
        fig.add_trace(
            go.Histogram(x=career_lengths, nbinsx=15, showlegend=False),
            row=2, col=1
        )
    
    # Performance by career stage
    if len(valid_data) > 0:
        # Create career stage bins
        age_bins = pd.cut(valid_data['Age'], bins=[0, 25, 30, 35, 50], labels=['Young', 'Prime', 'Veteran', 'Late'])
        stage_performance = valid_data.groupby(age_bins)['WAR'].mean()
        
        fig.add_trace(
            go.Bar(x=stage_performance.index.astype(str), y=stage_performance.values, showlegend=False),
            row=2, col=2
        )
    
    # Update layout
    fig.update_layout(
        height=600,
        title_text="Age Curve Training Data Analysis",
        title_x=0.5
    )
    
    fig.show()
    
    print(f"✓ Performance visualizations created for {len(age_training_data)} records")
    
else:
    print("⚠ No data available for visualization")
# Out:
# 2.2: Creating performance visualizations...
# ✓ Performance visualizations created for 45435 records

# %% [markdown]
# ## Section 3: Interactive Player Analysis
#
# Analyze individual players showing historical performance, model accuracy, and age curve progression.

# %%
# Player analysis functions
print("SECTION 3: INTERACTIVE PLAYER ANALYSIS")
print("=" * 50)

def get_player_options():
    """
    Get list of available players for analysis.
    """
    if len(age_training_data) == 0:
        return []
    
    # Get players with sufficient data
    player_counts = age_training_data.groupby('Name').size()
    qualified_players = player_counts[player_counts >= 2].index.tolist()
    
    # Sort alphabetically
    qualified_players.sort()
    
    return qualified_players

def analyze_player_historical_performance(player_name, data):
    """
    Analyze historical performance for a specific player.
    Keeps WARP and WAR separate as distinct metrics - no averaging/merging.
    """
    player_data = data[data['Name'] == player_name].copy()
    
    if len(player_data) == 0:
        return None
    
    # Sort by season
    player_data = player_data.sort_values('Season')
    
    # Separate WARP and WAR data
    warp_data = player_data[player_data['DataSource'] == 'WARP'].copy()
    war_data = player_data[player_data['DataSource'] == 'WAR'].copy()
    
    # Calculate separate career totals (the RIGHT way)
    career_warp = warp_data['WAR'].sum() if len(warp_data) > 0 else 0  # Column is called 'WAR' but contains WARP values for WARP records
    career_war = war_data['WAR'].sum() if len(war_data) > 0 else 0
    
    # Peak seasons for each metric
    peak_warp = warp_data['WAR'].max() if len(warp_data) > 0 else 0
    peak_war = war_data['WAR'].max() if len(war_data) > 0 else 0
    
    peak_warp_season = warp_data.loc[warp_data['WAR'].idxmax(), 'Season'] if len(warp_data) > 0 else None
    peak_war_season = war_data.loc[war_data['WAR'].idxmax(), 'Season'] if len(war_data) > 0 else None
    
    # Calculate basic statistics
    analysis = {
        'seasons': player_data['Season'].tolist(),
        'ages': player_data['Age'].tolist(),
        'war_values': player_data['WAR'].tolist(),
        'positions': player_data['Primary_Position'].tolist(),
        'data_sources': player_data['DataSource'].tolist(),
        
        # Separate career totals (CLEAN approach)
        'career_warp': career_warp,
        'career_war': career_war,
        'peak_warp': peak_warp,
        'peak_war': peak_war,
        'peak_warp_season': peak_warp_season,
        'peak_war_season': peak_war_season,
        
        # Additional info
        'age_range': f"{player_data['Age'].min():.0f}-{player_data['Age'].max():.0f}",
        'primary_position': player_data['Primary_Position'].mode().iloc[0] if len(player_data['Primary_Position'].mode()) > 0 else 'Unknown',
        'warp_seasons': len(warp_data),
        'war_seasons': len(war_data),
        'total_records': len(player_data)
    }
    
    return analysis

def create_player_visualization(player_analysis, player_name):
    """
    Create visualization for player's historical performance and age curve.
    Shows separate WARP and WAR metrics.
    """
    if player_analysis is None:
        return None
    
    fig = make_subplots(
        rows=2, cols=2,
        subplot_titles=(
            f'{player_name} - WAR/WARP by Season',
            f'{player_name} - WAR/WARP by Age',
            'Age Curve Progression',
            'Performance Summary'
        ),
        specs=[[{"secondary_y": False}, {"secondary_y": False}],
               [{"secondary_y": False}, {"type": "table"}]]
    )
    
    # WAR/WARP by season (color-coded by source)
    colors = ['red' if ds == 'WARP' else 'blue' for ds in player_analysis['data_sources']]
    fig.add_trace(
        go.Scatter(
            x=player_analysis['seasons'],
            y=player_analysis['war_values'],
            mode='lines+markers',
            name='Performance',
            line=dict(width=2),
            marker=dict(size=8, color=colors),
            text=[f"{s} ({ds})" for s, ds in zip(player_analysis['seasons'], player_analysis['data_sources'])],
            showlegend=False
        ),
        row=1, col=1
    )
    
    # WAR/WARP by age (color-coded by source)
    fig.add_trace(
        go.Scatter(
            x=player_analysis['ages'],
            y=player_analysis['war_values'],
            mode='markers',
            marker=dict(size=10, color=colors),
            text=[f"{s} ({ds})" for s, ds in zip(player_analysis['seasons'], player_analysis['data_sources'])],
            showlegend=False
        ),
        row=1, col=2
    )
    
    # Age curve (theoretical)
    if age_curve_model is not None:
        try:
            ages_range = np.arange(20, 40, 0.5)
            position = player_analysis['primary_position']
            
            age_factors = [age_curve_model.calculate_age_curve_factor(age, position) for age in ages_range]
            
            fig.add_trace(
                go.Scatter(
                    x=ages_range,
                    y=age_factors,
                    mode='lines',
                    name='Age Curve',
                    line=dict(width=2, dash='dash'),
                    showlegend=False
                ),
                row=2, col=1
            )
            
            # Add player's actual ages
            player_factors = [age_curve_model.calculate_age_curve_factor(age, position) for age in player_analysis['ages']]
            fig.add_trace(
                go.Scatter(
                    x=player_analysis['ages'],
                    y=player_factors,
                    mode='markers',
                    marker=dict(size=8, color='red'),
                    name='Player Ages',
                    showlegend=False
                ),
                row=2, col=1
            )
            
        except Exception as e:
            print(f"Age curve calculation failed: {e}")
    
    # Summary table - Show BOTH metrics separately
    summary_data = [
        ['Career WARP', f"{player_analysis['career_warp']:.1f}"],
        ['Career WAR', f"{player_analysis['career_war']:.1f}"], 
        ['Peak WARP', f"{player_analysis['peak_warp']:.1f}" if player_analysis['peak_warp'] > 0 else 'N/A'],
        ['Peak WAR', f"{player_analysis['peak_war']:.1f}" if player_analysis['peak_war'] > 0 else 'N/A'],
        ['Age Range', player_analysis['age_range']],
        ['Position', player_analysis['primary_position']]
    ]
    
    fig.add_trace(
        go.Table(
            header=dict(values=['Metric', 'Value']),
            cells=dict(values=[[item[0] for item in summary_data], [item[1] for item in summary_data]])
        ),
        row=2, col=2
    )
    
    # Update layout
    fig.update_layout(
        height=700,
        title_text=f"Player Analysis: {player_name}",
        title_x=0.5
    )
    
    fig.update_xaxes(title_text="Season", row=1, col=1)
    fig.update_yaxes(title_text="WAR/WARP", row=1, col=1)
    fig.update_xaxes(title_text="Age", row=1, col=2)
    fig.update_yaxes(title_text="WAR/WARP", row=1, col=2)
    fig.update_xaxes(title_text="Age", row=2, col=1)
    fig.update_yaxes(title_text="Age Factor", row=2, col=1)
    
    return fig

# Get available players
available_players = get_player_options()
print(f"\n3.1: Available players for analysis: {len(available_players)}")

if len(available_players) > 0:
    print("\nTop 20 players (alphabetical):")
    for i, player in enumerate(available_players[:20]):
        print(f"   {i+1:2d}. {player}")
    
    if len(available_players) > 20:
        print(f"   ... and {len(available_players) - 20} more players")
else:
    print("⚠ No players available for analysis")
# Out:
# SECTION 3: INTERACTIVE PLAYER ANALYSIS
# ==================================================
#
# 3.1: Available players for analysis: 2954
#
# Top 20 players (alphabetical):
#     1. A.J. Alexy
#     2. A.J. Cole
#     3. A.J. Ellis
#     4. A.J. Griffin
#     5. A.J. Jimenez
#     6. A.J. Minter
#     7. A.J. Pierzynski
#     8. A.J. Puk
#     9. A.J. Schugel
#    10. AJ Pollock
#    11. AJ Ramos
#    12. AJ Reed
#    13. AJ Smith-Shawver
#    14. Aaron Altherr
#    15. Aaron Ashby
#    16. Aaron Barrett
#    17. Aaron Blair
#    18. Aaron Brooks
#    19. Aaron Bummer
#    20. Aaron Civale
#    ... and 2934 more players

# %%
# Interactive player selection and analysis
from legacy_modules.improved_player_analysis import analyze_player_historical_performance_improved, create_improved_player_visualization

print("\n3.2: Interactive Player Analysis")
print("-" * 40)

if len(available_players) > 0:
    # Default to a well-known player if available
    default_players = ['Mike Trout', 'Shohei Ohtani', 'Ronald Acuña Jr.', 'Mookie Betts', 'Aaron Judge']
    selected_player = None
    
    for default in default_players:
        if default in available_players:
            selected_player = default
            break
    
    if selected_player is None:
        selected_player = available_players[0]
    
    print(f"Analyzing player: {selected_player}")
    print("(Change the 'selected_player' variable above to analyze a different player)")
    
    # Analyze the selected player
    player_analysis = analyze_player_historical_performance_improved(selected_player, age_training_data)
    
    if player_analysis:
        print(f"\n✓ Analysis completed for {selected_player}:")
        
        # Show separate WARP and WAR totals (CLEAN approach)
        if player_analysis['career_warp'] > 0:
            print(f"   Career WARP: {player_analysis['career_warp']:.1f} ({player_analysis['warp_seasons']} seasons)")
            print(f"   Peak WARP: {player_analysis['peak_warp']:.1f} ({player_analysis['peak_warp_season']})")
            
        if player_analysis['career_war'] > 0:
            print(f"   Career WAR: {player_analysis['career_war']:.1f} ({player_analysis['war_seasons']} seasons)")
            print(f"   Peak WAR: {player_analysis['peak_war']:.1f} ({player_analysis['peak_war_season']})")
            
        print(f"   Age Range: {player_analysis['age_range']} years")
        print(f"   Primary Position: {player_analysis['primary_position']}")
        print(f"   Total Records: {player_analysis['total_records']} (WARP: {player_analysis['warp_seasons']}, WAR: {player_analysis['war_seasons']})")
        
        # Create visualization
        player_fig = create_improved_player_visualization(player_analysis, selected_player)
        if player_fig:
            player_fig.show()
    else:
        print(f"⚠ Could not analyze {selected_player}")
        
else:
    print("⚠ No players available for analysis")
    selected_player = None
    player_analysis = None
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Interactive player selection and analysis
# ----> 2 from legacy_modules.improved_player_analysis import analyze_player_historical_performance_improved, create_improved_player_visualization
#       4 print("\n3.2: Interactive Player Analysis")
#       5 print("-" * 40)
#
# ModuleNotFoundError: No module named 'legacy_modules.improved_player_analysis'

# %% [markdown]
# ## Section 4: Future Projections (2025-2027)
#
# Generate 3-year future projections using the joint longitudinal-survival model, showing expected performance and career risk.

# %%
# Future projections
print("SECTION 4: FUTURE PROJECTIONS (2025-2027)")
print("=" * 50)

def generate_player_future_projections(player_name, data, age_model, metric_preference='WAR'):
    """
    Generate 3-year future projections for a player.
    Uses clean separation of WARP vs WAR - no averaging/merging.
    
    Args:
        player_name: Player to analyze
        data: Training data
        age_model: Age curve model
        metric_preference: 'WAR' or 'WARP' - which metric to use for projections
    """
    player_data = data[data['Name'] == player_name].copy()
    
    if len(player_data) == 0:
        return None
    
    # Filter to preferred metric only (CLEAN approach)
    preferred_data = player_data[player_data['DataSource'] == metric_preference].copy()
    
    # Fallback to other metric if preferred not available
    if len(preferred_data) == 0:
        fallback_metric = 'WARP' if metric_preference == 'WAR' else 'WAR'
        preferred_data = player_data[player_data['DataSource'] == fallback_metric].copy()
        metric_preference = fallback_metric
        print(f"   Using {metric_preference} data (preferred metric not available)")
    
    if len(preferred_data) == 0:
        return None
    
    # Get most recent season data from the preferred metric
    latest_season = preferred_data['Season'].max()
    latest_record = preferred_data[preferred_data['Season'] == latest_season].iloc[0]
    
    # Current state
    current_state = {
        'age': latest_record['Age'],
        'position': latest_record['Primary_Position'],
        'war': latest_record['WAR'],  # Note: column name is 'WAR' but contains WARP values for WARP records
        'season': latest_record['Season'],
        'metric_used': metric_preference
    }
    
    projections = {
        'current_state': current_state,
        'projections': {},
        'survival_probs': {},
        'age_factors': {}
    }
    
    try:
        if age_model is not None and model_trained:
            # Use trained model for projections
            future_projections = age_model.generate_future_projections(current_state, years_ahead=3)
            
            # Get survival probabilities
            survival_probs = age_model.calculate_survival_probabilities(
                current_state['age'], 
                current_state['position'], 
                current_state['war'], 
                years_ahead=3
            )
            
            # Get performance trajectory (without survival weighting)
            performance_path = age_model.predict_performance_path(
                current_state['age'],
                current_state['position'],
                current_state['war'],
                years_ahead=3
            )
            
            # Organize results
            projection_years = [2025, 2026, 2027]
            
            for i, year in enumerate(projection_years):
                if i < len(performance_path):
                    age_factor = age_model.calculate_age_curve_factor(
                        current_state['age'] + i + 1, 
                        current_state['position']
                    )
                    
                    projections['projections'][year] = {
                        'raw_war': performance_path[i],
                        'expected_war': future_projections.get(f'year_{i+1}', 0),
                        'age': current_state['age'] + i + 1
                    }
                    
                    projections['survival_probs'][year] = survival_probs[i] if i < len(survival_probs) else 0.1
                    projections['age_factors'][year] = age_factor
        
        else:
            # Fallback: simple age-based projections
            print("Using simplified age curve projections (model not available)")
            
            projection_years = [2025, 2026, 2027]
            
            for i, year in enumerate(projection_years):
                future_age = current_state['age'] + i + 1
                
                # Simple aging assumption
                if future_age <= 27:
                    age_factor = 1.02  # Slight improvement
                elif future_age <= 30:
                    age_factor = 1.0   # Peak
                else:
                    decline_rate = 0.02 if current_state['position'] != 'C' else 0.03
                    age_factor = 1.0 - (future_age - 30) * decline_rate
                
                age_factor = max(0.1, age_factor)
                projected_war = current_state['war'] * age_factor
                
                # Simple survival probability
                survival_prob = max(0.5, 1.0 - (future_age - current_state['age']) * 0.05)
                
                projections['projections'][year] = {
                    'raw_war': projected_war,
                    'expected_war': projected_war * survival_prob,
                    'age': future_age
                }
                
                projections['survival_probs'][year] = survival_prob
                projections['age_factors'][year] = age_factor
                
    except Exception as e:
        print(f"Projection generation failed: {e}")
        return None
    
    return projections


def create_projection_visualization(projections, player_name):
    """
    Create visualization for future projections.
    Clearly shows which metric is being used.
    """
    if projections is None:
        return None
    
    metric_used = projections['current_state']['metric_used']
    
    fig = make_subplots(
        rows=2, cols=2,
        subplot_titles=(
            f'{player_name} - Future {metric_used} Projections',
            'Survival Probabilities',
            'Age Curve Factors',
            'Projection Summary'
        ),
        specs=[[{"secondary_y": False}, {"secondary_y": False}],
               [{"secondary_y": False}, {"type": "table"}]]
    )
    
    # Extract data for plotting
    years = list(projections['projections'].keys())
    raw_wars = [projections['projections'][year]['raw_war'] for year in years]
    expected_wars = [projections['projections'][year]['expected_war'] for year in years]
    survival_probs = [projections['survival_probs'][year] for year in years]
    age_factors = [projections['age_factors'][year] for year in years]
    ages = [projections['projections'][year]['age'] for year in years]
    
    # WAR/WARP projections
    fig.add_trace(
        go.Bar(
            x=years,
            y=raw_wars,
            name=f'Raw {metric_used}',
            opacity=0.7,
            showlegend=False
        ),
        row=1, col=1
    )
    
    fig.add_trace(
        go.Scatter(
            x=years,
            y=expected_wars,
            mode='lines+markers',
            name=f'Expected {metric_used}',
            line=dict(color='red', width=3),
            marker=dict(size=8),
            showlegend=False
        ),
        row=1, col=1
    )
    
    # Survival probabilities
    fig.add_trace(
        go.Bar(
            x=years,
            y=[p * 100 for p in survival_probs],
            name='Survival %',
            marker_color='green',
            showlegend=False
        ),
        row=1, col=2
    )
    
    # Age factors
    fig.add_trace(
        go.Scatter(
            x=years,
            y=age_factors,
            mode='lines+markers',
            name='Age Factor',
            line=dict(width=3),
            marker=dict(size=8),
            showlegend=False
        ),
        row=2, col=1
    )
    
    # Summary table
    current = projections['current_state']
    total_projected = sum(expected_wars)
    
    summary_data = [
        ['Metric Used', metric_used],
        ['Current Age', f"{current['age']:.0f}"],
        [f'Current {metric_used}', f"{current['war']:.1f}"],
        ['Position', current['position']],
        [f'3-Year Total', f"{total_projected:.1f} {metric_used}"],
        [f'2025 Projection', f"{expected_wars[0]:.1f} {metric_used}"]
    ]
    
    fig.add_trace(
        go.Table(
            header=dict(values=['Metric', 'Value']),
            cells=dict(values=[[item[0] for item in summary_data], [item[1] for item in summary_data]])
        ),
        row=2, col=2
    )
    
    # Update layout
    fig.update_layout(
        height=700,
        title_text=f"Future Projections: {player_name} (2025-2027) - Using {metric_used}",
        title_x=0.5
    )
    
    fig.update_xaxes(title_text="Year", row=1, col=1)
    fig.update_yaxes(title_text=f"{metric_used}", row=1, col=1)
    fig.update_xaxes(title_text="Year", row=1, col=2)
    fig.update_yaxes(title_text="Survival %", row=1, col=2)
    fig.update_xaxes(title_text="Year", row=2, col=1)
    fig.update_yaxes(title_text="Age Factor", row=2, col=1)
    
    return fig

print("\n4.1: Future projection functions loaded")

# %%
# Generate projections for the selected player
print("\n4.2: Generating future projections...")

if selected_player and player_analysis:
    print(f"Generating 2025-2027 projections for {selected_player}...")
    print("Using WAR as primary metric for projections (change metric_preference parameter to use WARP)")
    
    # Generate projections using clean WAR/WARP separation
    future_projections = generate_player_future_projections(
        selected_player, 
        age_training_data, 
        age_curve_model,
        metric_preference='WAR'  # Change to 'WARP' if you prefer WARP projections
    )
    
    if future_projections:
        metric_used = future_projections['current_state']['metric_used']
        print(f"\n✓ Projections generated for {selected_player} using {metric_used}:")
        
        current = future_projections['current_state']
        print(f"\nCurrent State ({current['season']}):")
        print(f"   Age: {current['age']:.0f}")
        print(f"   Position: {current['position']}")
        print(f"   {metric_used}: {current['war']:.1f}")
        print(f"   Metric Used: {metric_used}")
        
        print(f"\nFuture {metric_used} Projections:")
        total_expected = 0
        
        for year in [2025, 2026, 2027]:
            if year in future_projections['projections']:
                proj = future_projections['projections'][year]
                survival = future_projections['survival_probs'][year]
                age_factor = future_projections['age_factors'][year]
                
                print(f"   {year} (Age {proj['age']:.0f}): {proj['expected_war']:.1f} {metric_used}")
                print(f"        Raw: {proj['raw_war']:.1f}, Survival: {survival*100:.0f}%, Age Factor: {age_factor:.3f}")
                
                total_expected += proj['expected_war']
        
        print(f"\n3-Year Total Expected {metric_used}: {total_expected:.1f}")
        print(f"(This is ONLY {metric_used} - not averaged with other metrics)")
        
        # Create visualization
        projection_fig = create_projection_visualization(future_projections, selected_player)
        if projection_fig:
            projection_fig.show()
            
    else:
        print(f"⚠ Could not generate projections for {selected_player}")
        
else:
    print("⚠ No player selected for projection analysis")

# %% [markdown]
# ## Section 5: Model Comparison and Analysis
#
# Compare the joint age curve model with baseline predictions and analyze the impact of aging adjustments.

# %%
# Model comparison and analysis
print("SECTION 5: MODEL COMPARISON AND ANALYSIS")
print("=" * 50)

def compare_models_for_players(players_list, data, age_model):
    """
    Compare age-adjusted vs baseline projections for multiple players.
    """
    comparison_results = []
    
    for player_name in players_list[:10]:  # Limit to 10 players for performance
        try:
            # Get player projections
            projections = generate_player_future_projections(player_name, data, age_model)
            
            if projections:
                current = projections['current_state']
                
                # Calculate simple baseline (no aging adjustment)
                baseline_projection = current['war'] * 3  # Assume constant performance
                
                # Age-adjusted projection
                age_adjusted = sum([projections['projections'][year]['expected_war'] 
                                  for year in [2025, 2026, 2027] 
                                  if year in projections['projections']])
                
                # Aging impact
                aging_impact = age_adjusted - baseline_projection
                
                comparison_results.append({
                    'player': player_name,
                    'age': current['age'],
                    'position': current['position'],
                    'current_war': current['war'],
                    'baseline_3yr': baseline_projection,
                    'age_adjusted_3yr': age_adjusted,
                    'aging_impact': aging_impact,
                    'impact_pct': (aging_impact / baseline_projection * 100) if baseline_projection != 0 else 0
                })
                
        except Exception as e:
            print(f"Error processing {player_name}: {e}")
            continue
    
    return pd.DataFrame(comparison_results)

print("\n5.1: Comparing age-adjusted vs baseline projections...")

if len(available_players) > 0:
    # Select diverse players for comparison
    comparison_players = available_players[:20]  # Top 20 players
    
    comparison_df = compare_models_for_players(comparison_players, age_training_data, age_curve_model)
    
    if len(comparison_df) > 0:
        print(f"\n✓ Model comparison completed for {len(comparison_df)} players")
        
        # Show summary statistics
        print(f"\nAging Impact Summary:")
        print(f"   Average impact: {comparison_df['aging_impact'].mean():.1f} WAR over 3 years")
        print(f"   Impact range: {comparison_df['aging_impact'].min():.1f} to {comparison_df['aging_impact'].max():.1f} WAR")
        print(f"   Players helped by aging: {(comparison_df['aging_impact'] > 0).sum()}")
        print(f"   Players hurt by aging: {(comparison_df['aging_impact'] < 0).sum()}")
        
        # Top beneficiaries and victims of aging
        print(f"\nTop 5 helped by age curve:")
        top_helped = comparison_df.nlargest(5, 'aging_impact')
        for _, row in top_helped.iterrows():
            print(f"   {row['player']} (Age {row['age']:.0f}): +{row['aging_impact']:.1f} WAR")
            
        print(f"\nTop 5 hurt by age curve:")
        top_hurt = comparison_df.nsmallest(5, 'aging_impact')
        for _, row in top_hurt.iterrows():
            print(f"   {row['player']} (Age {row['age']:.0f}): {row['aging_impact']:.1f} WAR")
            
    else:
        print("⚠ No successful model comparisons")
        comparison_df = pd.DataFrame()
        
else:
    print("⚠ No players available for comparison")
    comparison_df = pd.DataFrame()

# %%
# Visualization of model comparison
print("\n5.2: Creating model comparison visualizations...")

if len(comparison_df) > 0:
    
    fig = make_subplots(
        rows=2, cols=2,
        subplot_titles=(
            'Aging Impact by Current Age',
            'Aging Impact by Position',
            'Baseline vs Age-Adjusted Projections',
            'Impact Distribution'
        )
    )
    
    # Aging impact by age
    fig.add_trace(
        go.Scatter(
            x=comparison_df['age'],
            y=comparison_df['aging_impact'],
            mode='markers',
            marker=dict(size=8, opacity=0.7),
            text=comparison_df['player'],
            name='Impact by Age',
            showlegend=False
        ),
        row=1, col=1
    )
    
    # Add zero line
    fig.add_hline(y=0, line_dash="dash", line_color="red", row=1, col=1)
    
    # Aging impact by position
    position_impact = comparison_df.groupby('position')['aging_impact'].mean().reset_index()
    fig.add_trace(
        go.Bar(
            x=position_impact['position'],
            y=position_impact['aging_impact'],
            name='Avg Impact by Position',
            showlegend=False
        ),
        row=1, col=2
    )
    
    # Baseline vs age-adjusted scatter
    fig.add_trace(
        go.Scatter(
            x=comparison_df['baseline_3yr'],
            y=comparison_df['age_adjusted_3yr'],
            mode='markers',
            marker=dict(size=8, opacity=0.7),
            text=comparison_df['player'],
            name='Baseline vs Adjusted',
            showlegend=False
        ),
        row=2, col=1
    )
    
    # Add diagonal line (y=x)
    min_val = min(comparison_df['baseline_3yr'].min(), comparison_df['age_adjusted_3yr'].min())
    max_val = max(comparison_df['baseline_3yr'].max(), comparison_df['age_adjusted_3yr'].max())
    fig.add_trace(
        go.Scatter(
            x=[min_val, max_val],
            y=[min_val, max_val],
            mode='lines',
            line=dict(dash='dash', color='red'),
            name='No Change Line',
            showlegend=False
        ),
        row=2, col=1
    )
    
    # Impact distribution histogram
    fig.add_trace(
        go.Histogram(
            x=comparison_df['aging_impact'],
            nbinsx=15,
            name='Impact Distribution',
            showlegend=False
        ),
        row=2, col=2
    )
    
    # Update layout
    fig.update_layout(
        height=700,
        title_text="Age Curve Model Impact Analysis",
        title_x=0.5
    )
    
    # Update axis labels
    fig.update_xaxes(title_text="Age", row=1, col=1)
    fig.update_yaxes(title_text="Aging Impact (WAR)", row=1, col=1)
    fig.update_xaxes(title_text="Position", row=1, col=2)
    fig.update_yaxes(title_text="Avg Impact (WAR)", row=1, col=2)
    fig.update_xaxes(title_text="Baseline 3-Yr WAR", row=2, col=1)
    fig.update_yaxes(title_text="Age-Adjusted 3-Yr WAR", row=2, col=1)
    fig.update_xaxes(title_text="Aging Impact (WAR)", row=2, col=2)
    fig.update_yaxes(title_text="Count", row=2, col=2)
    
    fig.show()
    
    print("✓ Model comparison visualizations created")
    
else:
    print("⚠ No comparison data available for visualization")

# %% [markdown]
# ## Section 6: Summary and Insights
#
# Summarize key findings from the age curve analysis and provide actionable insights for player evaluation.

# %%
# Summary and insights
print("SECTION 6: SUMMARY AND INSIGHTS")
print("=" * 50)

print("\n6.1: Age Curve Analysis Summary")
print("-" * 35)

# Model performance summary
if model_trained:
    print("✓ Joint longitudinal-survival model successfully trained")
    print("✓ Addresses selection bias in traditional aging curves")
    print("✓ Integrates performance trajectory with retirement risk")
    
    if validation_completed:
        print(f"✓ Cross-validation completed with temporal splits")
        for metric, value in validation_results.items():
            if 'mean' in metric and not np.isnan(value):
                print(f"   {metric}: {value:.3f}")
else:
    print("⚠ Limited model functionality due to training constraints")
    print("✓ Simplified age curve projections available")

# Data summary
print(f"\nData Coverage:")
print(f"   Total records: {len(age_training_data)}")
print(f"   Age coverage: {age_training_data['Age'].notna().sum()}/{len(age_training_data)} ({age_training_data['Age'].notna().sum()/len(age_training_data)*100:.1f}%)")
print(f"   Season range: {age_training_data['Season'].min()}-{age_training_data['Season'].max()}")
print(f"   Available players: {len(available_players)}")

# Age curve insights
print(f"\nAge Curve Insights:")
if len(comparison_df) > 0:
    young_players = comparison_df[comparison_df['age'] <= 26]
    prime_players = comparison_df[(comparison_df['age'] > 26) & (comparison_df['age'] <= 30)]
    veteran_players = comparison_df[comparison_df['age'] > 30]
    
    print(f"   Young players (≤26): Avg impact +{young_players['aging_impact'].mean():.1f} WAR (improvement expected)")
    print(f"   Prime players (27-30): Avg impact {prime_players['aging_impact'].mean():.1f} WAR (peak performance)")
    print(f"   Veteran players (>30): Avg impact {veteran_players['aging_impact'].mean():.1f} WAR (decline phase)")
    
    # Position-specific insights
    print(f"\nPosition-Specific Patterns:")
    for position in ['C', 'SS', '1B', 'DH', 'P']:
        pos_data = comparison_df[comparison_df['position'] == position]
        if len(pos_data) > 0:
            print(f"   {position}: Avg impact {pos_data['aging_impact'].mean():.1f} WAR ({len(pos_data)} players)")

print(f"\n6.2: Key Findings")
print("-" * 20)

findings = [
    "Joint modeling accounts for survival bias in aging curves",
    "Position-specific aging patterns significantly impact projections",
    "Young players benefit from upward age adjustments",
    "Veteran players face realistic decline projections",
    "Catchers show steeper decline rates than other positions",
    "DH players maintain performance longer due to reduced physical demands"
]

for i, finding in enumerate(findings, 1):
    print(f"   {i}. {finding}")

print(f"\n6.3: Practical Applications")
print("-" * 25)

applications = [
    "Free Agent Evaluation: Age-adjusted 3-year projections for contract analysis",
    "Trade Analysis: Account for aging when evaluating future value",
    "Roster Planning: Understand team age distribution impact",
    "Contract Extensions: Realistic expectations for aging players",
    "Draft Strategy: Value young talent with upside potential",
    "Position Changes: Anticipate defensive decline for planning"
]

for i, app in enumerate(applications, 1):
    print(f"   {i}. {app}")

print(f"\n" + "=" * 60)
print(f"sWARm Age Curve Analysis Complete!")
print(f"Analysis Date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

if selected_player and future_projections:
    total_war = sum([future_projections['projections'][year]['expected_war'] 
                    for year in [2025, 2026, 2027] 
                    if year in future_projections['projections']])
    print(f"\nFeatured Analysis: {selected_player}")
    print(f"2025-2027 Projection: {total_war:.1f} total expected WAR")

print(f"" + "=" * 60)

# %% [markdown]
# ## Interactive Section: Custom Player Analysis
#
# Use this section to analyze any specific player by changing the `custom_player` variable below.

# %%
# Custom player analysis
print("INTERACTIVE SECTION: CUSTOM PLAYER ANALYSIS")
print("=" * 50)

# CHANGE THIS VARIABLE TO ANALYZE ANY PLAYER
custom_player = "Mike Trout"  # Change this to any player name

print(f"\nAnalyzing: {custom_player}")
print("(Edit the 'custom_player' variable above to analyze a different player)")

if custom_player in available_players:
    # Historical analysis
    custom_analysis = analyze_player_historical_performance(custom_player, age_training_data)
    
    if custom_analysis:
        print(f"\n📊 Historical Performance ({custom_player}):")
        print(f"   Career WAR: {custom_analysis['career_war']:.1f}")
        print(f"   Peak WAR: {custom_analysis['peak_war']:.1f} ({custom_analysis['peak_season']})")
        print(f"   Age Range: {custom_analysis['age_range']} years")
        print(f"   Primary Position: {custom_analysis['primary_position']}")
        print(f"   Seasons: {len(custom_analysis['seasons'])}")
        
        # Future projections
        custom_projections = generate_player_future_projections(
            custom_player, age_training_data, age_curve_model
        )
        
        if custom_projections:
            print(f"\n🔮 Future Projections (2025-2027):")
            
            current = custom_projections['current_state']
            print(f"   Current Age: {current['age']:.0f}")
            print(f"   Current WAR: {current['war']:.1f} ({current['season']})")
            
            total_expected = 0
            for year in [2025, 2026, 2027]:
                if year in custom_projections['projections']:
                    proj = custom_projections['projections'][year]
                    survival = custom_projections['survival_probs'][year]
                    total_expected += proj['expected_war']
                    print(f"   {year}: {proj['expected_war']:.1f} WAR (Age {proj['age']:.0f}, {survival*100:.0f}% survival)")
            
            print(f"   \n💰 3-Year Value: {total_expected:.1f} expected WAR")
            
            # Create visualization
            custom_fig = create_player_visualization(custom_analysis, custom_player)
            if custom_fig:
                custom_fig.show()
                
            custom_proj_fig = create_projection_visualization(custom_projections, custom_player)
            if custom_proj_fig:
                custom_proj_fig.show()
                
        else:
            print(f"   ⚠ Could not generate projections")
            
    else:
        print(f"   ⚠ Could not analyze historical performance")
        
elif len(available_players) > 0:
    print(f"\n⚠ Player '{custom_player}' not found in dataset")
    print(f"\nAvailable players (first 10):")
    for i, player in enumerate(available_players[:10]):
        print(f"   {player}")
    if len(available_players) > 10:
        print(f"   ... and {len(available_players) - 10} more")
        
else:
    print("\n⚠ No players available for analysis")

print(f"\n" + "-" * 60)
print("End of Analysis")
